# %%
#单元格1
import os
import sys
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from trainTest.metrics.get_test_metrics import PlotConfusionMatrix
import torch.nn.functional as F
import warnings

warnings.filterwarnings("ignore")

# --- 关键：确保项目根目录在路径中 ---
path = os.path.join(os.getcwd(), '..', '..')
sys.path.append(path)

# --- 导入您的项目文件 ---
from utils.common_utils import printlog, set_seed, make_dir, calculate_and_save_metrics
from utils.common_params import * #
from models.LD_Net import LD_Net
from models.CNNRNNs import CNNRNNs
from trainTest.early_stopping.early_stopping import EarlyStopping
from trainTest.optimizers.get_optimizer import Optimizer
from trainTest.losses.get_loss import get_classification_loss
from trainTest.lr_schedulers.get_lr_scheduler import LrScheduler

# --- 💡 关键修正：为本地指标函数导入依赖 ---
from trainTest.metrics.metrics_utils import (
    get_accuracy, get_precision, get_recall, get_f1, get_specificity
)
from sklearn.metrics import roc_auc_score
# --- 修正结束 ---

# 设置随机种子
set_seed(seed=42)
print("所有依赖导入成功。")
# Out:
# 所有依赖导入成功。

# %%
#单元格2
# === 1. 数据集选择 (修复 NameError) ===
DATASET_NAME = "SIAT"
MODEL_TYPE = 'SC-BiGRU_FocalLoss_1C'  # 我们用这个名字来代表 CNNRNNs(rnn_type='BiGRU')
DENOISE_METHOD = 'LD_Net_Online_Classification'  # 文件夹名
n_channels_check = 9

# === 2. 关键路径设置 ===

# --- 💡 关键修正 1: LD-Net (降噪器) 的路径 ---
LD_NET_MODEL_PATH = os.path.join(
    os.getcwd(),
    'checkpoints', 'LD_Net_SIAT', 'ld_net_best_model.pth'
)

# --- 💡 关键修正 2: *噪声输入* (分类器输入) 的路径 ---
base_data_path = os.path.join(path, "preProcessing")  # 'path' 是根目录
DATA_DIR = os.path.join(
    base_data_path, "SIAT_LLMD_trainData", "Denoising_TrainSet_XY"
)

# --- 3. 模型与训练设置 ---
BATCH_SIZE = 64
LEARNING_RATE = 5e-4
EPOCHS = 200
PATIENCE = 30
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === 4. 检查参数 ===
print(f"--- 步骤四: LD-Net + {MODEL_TYPE} ---")
print(f"设备: {DEVICE}")
print(f"将加载 LD-Net 降噪器: {LD_NET_MODEL_PATH}")
print(f"将加载 *成对数据* (X, Y) 源: {DATA_DIR}")
if C != n_channels_check:
    print(f"⚠️ 警告: common_params.py 中的 C={C} 与 SIAT (C=9) 不匹配!")
else:
    print("✅ C 参数检查通过。")

# === 5. 结果保存路径 (💡 关键修正) ===
# 1. 创建包含模型名称的根目录 (例如: .../LD_Net_Online_Classification/SC_BiGRU/)
save_dir_root = os.path.join(path, 'results', DENOISE_METHOD, MODEL_TYPE)
# 2. 让模型目录和根目录是同一个地方
save_dir_models_temp = save_dir_root # <-- 指向同一个路径
make_dir(save_dir_root)

print(f"✅ 最终结果 (CSV/PNG) 将保存到: {save_dir_root}")
print(f"✅ 临时模型 (PTH) 将保存到: {save_dir_models_temp}")
# Out:
# --- 步骤四: LD-Net + SC-BiGRU_FocalLoss_1C ---
# 设备: cuda
# 将加载 LD-Net 降噪器: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\checkpoints\LD_Net_SIAT\ld_net_best_model.pth
# 将加载 *成对数据* (X, Y) 源: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\preProcessing\SIAT_LLMD_trainData\Denoising_TrainSet_XY
# ✅ C 参数检查通过。
# ✅ 最终结果 (CSV/PNG) 将保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C
# ✅ 临时模型 (PTH) 将保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C

# %%
#单元格3
print("--- 正在加载 LD-Net 降噪模型 (步骤三的结果) ---")
try:
    model_denoise = torch.load(LD_NET_MODEL_PATH, weights_only=False)
    model_denoise.to(DEVICE)
    model_denoise.eval()
    print("✅ LD-Net 降噪模型加载成功并设为 eval() 模式。")
except Exception as e:
    print(f"❌ 加载 LD-Net 模型失败: {e}")
    print("请确保 步骤三 已成功运行，且 LD_NET_MODEL_PATH 路径正确。")
    raise e
# Out:
# --- 正在加载 LD-Net 降噪模型 (步骤三的结果) ---
# ✅ LD-Net 降噪模型加载成功并设为 eval() 模式。

# %%
#单元格4
import glob


class LdNetClassificationDataset(Dataset):
    """
    用于分类器训练的数据集。
    从 步骤一 的 'Denoising_TrainSet_XY' 文件夹加载数据。
    """

    def __init__(self, data_dir, subject_id):
        self.data_dir = data_dir
        self.subject_id = subject_id

        # --- 匹配 'Denoising_TrainSet_XY' 的文件名 ---
        file_name_prefix = '_XY_TrainData.npz'
        search_path = os.path.join(self.data_dir, f"{self.subject_id}{file_name_prefix}")
        file_paths = glob.glob(search_path)

        if not file_paths:
            print(f"警告: 在 {self.data_dir} 中未找到 {self.subject_id}{file_name_prefix}。")
            self.samples = np.empty((0, C, window))
            self.labels_encoded = np.empty((0,))
            return

        try:
            data = np.load(file_paths[0])
            # 步骤一 保存的键是 'noisy_X' 和 'sub_motion_label_encoded'
            self.samples = data['noisy_X'].astype(np.float32)
            self.labels_encoded = data['sub_motion_label_encoded'].astype(np.int64)
            print(f"  已加载 {self.subject_id}: {self.samples.shape[0]} 个样本。")

        except Exception as e:
            print(f"加载 {file_paths[0]} 出错: {e}")
            self.samples = np.empty((0, C, window))
            self.labels_encoded = np.empty((0,))

    def __len__(self):
        return self.samples.shape[0]

    def __getitem__(self, idx):
        # 返回 噪声X 和 标签Y
        return self.samples[idx], self.labels_encoded[idx]


print("✅ 分类器数据集 (LdNetClassificationDataset) 定义完毕。")
# Out:
# ✅ 分类器数据集 (LdNetClassificationDataset) 定义完毕。

# %%
# 单元格 5 (方案 1-C: 固定 LD-Net + BiGRU + Focal Loss)
from sklearn.model_selection import train_test_split
from trainTest.metrics.get_test_metrics import PlotConfusionMatrix
import torch.optim as optim
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

# --- 💡 关键修改 (方案 1-C): 定义 Focal Loss ---
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)

        focal_loss = (1 - pt)**self.gamma * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss
# --- 修正结束 ---

# --- (本地指标函数 _calc_cls_metrics 保持不变) ---
def _calc_cls_metrics(y_true, y_pred, y_scores=None):
    y_true = np.asarray(y_true); y_pred = np.asarray(y_pred)
    metrics = {
        'Accuracy': get_accuracy(y_true, y_pred), 'Precision': get_precision(y_true, y_pred),
        'Recall': get_recall(y_true, y_pred), 'F1': get_f1(y_true, y_pred),
        'Specificity': get_specificity(y_true, y_pred),
    }
    auc_pct = 0.0
    if y_scores is not None:
        if isinstance(y_scores, list):
            try: y_scores = np.asarray(y_scores)
            except Exception: y_scores = None
        if isinstance(y_scores, np.ndarray) and y_scores.ndim == 2 and y_scores.shape[1] > 1:
            try:
                auc = roc_auc_score(y_true, y_scores, multi_class='ovr', average='macro')
                auc_pct = round(auc * 100.0, 3)
            except Exception: auc_pct = 0.0
    metrics['AUC'] = auc_pct
    return metrics
# --- 指标函数结束 ---

# --- 💡 关键修改 (方案 1-C): 简化的 "规整器" (1通道) ---
def _coerce_to_1x9xL(out, C_channels=9):
    if isinstance(out, (list, tuple)): t = out[0]
    else: t = out

    if t.dim() == 3 and t.size(1) == C_channels:
        return t.unsqueeze(1) # [B, 9, L] -> [B, 1, 9, L]
    elif t.dim() == 4 and t.size(1) == 1:
        return t # -> 已经是 [B, 1, 9, L]
    else:
        raise RuntimeError(f"LD-Net (eval) 输出形状 {tuple(t.shape)} 异常")
# --- 修正结束 ---


def train_one_epoch(model_classifier, model_denoiser, train_loader, criterion, optimizer, device):
    model_classifier.train()
    # (LD-Net 是冻结的)
    train_loss = 0.; total_num = 0
    y_true_all = []; y_pred_all = []

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        # (方案 1: 恢复 no_grad)
        with torch.no_grad():
            out = model_denoiser(inputs)
            inputs_denoised = _coerce_to_1x9xL(out, C_channels=C) # (使用 1ch 规整器)

        outputs = model_classifier(inputs_denoised)
        loss    = criterion(outputs, labels) # (Focal Loss)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        bs = labels.size(0)
        train_loss += loss.item() * bs; total_num  += bs
        y_true_all.extend(labels.detach().cpu().numpy())
        y_pred_all.extend(torch.max(outputs, 1)[1].detach().cpu().numpy())

    return train_loss/total_num, _calc_cls_metrics(y_true_all, y_pred_all, None)

@torch.no_grad()
def test_one_epoch(model_classifier, model_denoiser, test_loader, criterion, device):
    model_classifier.eval()
    model_denoiser.eval()
    test_loss, total_num = 0.0, 0
    y_true_all, y_pred_all, y_scores_all = [], [], []

    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        out_tensor = model_denoiser(inputs)
        x_in  = _coerce_to_1x9xL(out_tensor, C_channels=C) # (使用 1ch 规整器)

        outputs = model_classifier(x_in)
        loss    = criterion(outputs, labels) # (Focal Loss)

        bs = labels.size(0)
        test_loss  += loss.item() * bs; total_num  += bs
        y_true_all.extend(labels.detach().cpu().numpy())
        y_pred_all.extend(torch.max(outputs, 1)[1].detach().cpu().numpy())
        y_scores_all.extend(F.softmax(outputs, dim=1).detach().cpu().numpy())

    return test_loss/total_num, _calc_cls_metrics(y_true_all, y_pred_all, np.asarray(y_scores_all)), y_true_all, y_pred_all

def train_test_subject(subject_id, data_dir, model_denoise, device, save_dir_models_temp,
                       model_type, epochs, batch_size, lr, patience, exp_tim):

    # (LD-Net 是冻结的)

    # 1. 加载数据 (不变)
    dataset = LdNetClassificationDataset(data_dir=data_dir, subject_id=subject_id)
    if len(dataset) == 0: return None
    train_idx, test_idx = train_test_split(
        list(range(len(dataset))), test_size=0.2, random_state=exp_tim, stratify=dataset.labels_encoded
    )

    # (删除静态类权重计算)

    train_loader = DataLoader(torch.utils.data.Subset(dataset, train_idx), batch_size=batch_size, shuffle=True,  num_workers=0)
    test_loader  = DataLoader(torch.utils.data.Subset(dataset, test_idx),  batch_size=batch_size, shuffle=False, num_workers=0)

    # 2. 分类器
    # (恢复方案1: BiGRU)
    model_classifier = CNNRNNs(rnn_type='BiGRU').to(device)
    print("已实例化 SC-BiGRU 分类器。")

    # --- 💡 关键修改 (方案 1-C): 使用 Focal Loss ---
    criterion = FocalLoss(gamma=2).to(device) # (gamma=2 是标准值)
    print("  > 使用 FocalLoss (gamma=2) 作为损失函数。")
    # --- 修正结束 ---

    # 3. 优化器
    # (恢复方案1: 只训练分类器)
    print("正在为分类器设置优化器 (LD-Net 已冻结)...")
    optimizer = Optimizer(model=model_classifier, optimizer_type='Adam', lr=lr).get_optimizer()
    print(f"  > 使用 AdamW 优化器, lr={lr}")

    # 4. Scheduler & EarlyStopping (不变)
    scheduler_params = {
        'ReduceLROnPlateau': {
            'mode':'min','factor':0.1,'patience':5,'threshold':1e-4,'min_lr':1e-8
        }
    }
    scheduler = LrScheduler(optimizer=optimizer, scheduler_type='ReduceLROnPlateau',
                            params=scheduler_params,
                            max_epoch=epochs).get_scheduler()

    save_dir_subj = os.path.join(save_dir_models_temp, subject_id)
    make_dir(save_dir_subj)
    best_loss_path = os.path.join(save_dir_subj, f'best_loss_model_exp{exp_tim}.pth')
    early_stopping  = EarlyStopping(patience=patience, verbose=True, path=best_loss_path)

    best_acc = -1.0
    best_acc_path = os.path.join(save_dir_subj, f'best_acc_model_exp{exp_tim}.pth')

    # (辅助函数现在只保存分类器)
    def save_models_checkpoint(path):
        torch.save(model_classifier.state_dict(), path)

    # 5. 训练循环
    for epoch in range(1, epochs+1):
        train_loss, train_metrics = train_one_epoch(
            model_classifier, model_denoise,
            train_loader, criterion, optimizer, device
        )
        val_loss, val_metrics, _, _ = test_one_epoch(
            model_classifier, model_denoise,
            test_loader, criterion, device
        )

        scheduler.step(val_loss)

        # (恢复方案1: 只保存分类器)
        early_stopping(val_loss, model_classifier.state_dict())

        val_acc = val_metrics['Accuracy']
        if val_acc > best_acc:
            best_acc = val_acc
            save_models_checkpoint(best_acc_path)
            print(f"    {subject_id} | Exp {exp_tim} | 新的最佳准确率: {val_acc:.2f}% (已保存)")

        if (epoch % 10 == 0) or early_stopping.early_stop:
            print(f"{subject_id} | Exp {exp_tim} | Ep {epoch:03d} | "
                  f"Train {train_loss:.4f}/{train_metrics['Accuracy']:.2f}% | "
                  f"Val {val_loss:.4f}/{val_metrics['Accuracy']:.2f}%")
        if early_stopping.early_stop:
            print("早停触发 (基于 Val Loss)。"); break

    # 6. 加载最佳
    load_path = best_acc_path if os.path.exists(best_acc_path) else best_loss_path
    print(f"加载 {subject_id} (Exp {exp_tim}) 的最佳模型 (来自: {load_path})...")

    best_classifier = CNNRNNs(rnn_type='BiGRU').to(device)

    ckpt = torch.load(load_path)
    best_classifier.load_state_dict(ckpt)

    # 7. 最终评估
    test_loss_final, test_metrics_final, y_true_final, y_pred_final = test_one_epoch(
        best_classifier, model_denoise, test_loader, criterion, device
    )

    # 8. 混淆矩阵 (不变)
    print('正在计算并保存混淆矩阵...')
    motions_list_cm = ['WAK', 'STDUP', 'SITDN', 'UPS', 'DNS']
    cm_save_jpg_name = os.path.join(save_dir_subj, f'confusion_matrix_exp{exp_tim}.jpg')
    cm_save_csv_name = os.path.join(save_dir_subj, f'confusion_matrix_exp{exp_tim}.xlsx')
    plot_confusion_matrix = PlotConfusionMatrix(
        y_true_final, y_pred_final, label_type=motions_list_cm,
        show_type='all', plot=False, save_fig=True, save_results=True, cmap='YlGnBu'
    )
    plot_confusion_matrix.get_confusion_matrix(cm_save_jpg_name, cm_save_csv_name)
    print(f'混淆矩阵已保存到: {save_dir_subj}')

    test_metrics_final['Subject'] = subject_id
    return test_metrics_final

print("✅ 训练/测试函数 (train_test_subject) [方案 1-C: 固定LD-Net + BiGRU + FocalLoss] 定义完毕。")
# Out:
# ✅ 训练/测试函数 (train_test_subject) [方案 1-C: 固定LD-Net + BiGRU + FocalLoss] 定义完毕。

# %%
#单元格6
import pandas as pd
import numpy as np

# (来自 common_params.py)
subjects_list = ['Sub01', 'Sub02', 'Sub03', 'Sub04', 'Sub05', 'Sub31', 'Sub32', 'Sub33', 'Sub34', 'Sub35']

# 1. --- 初始化列表 ---
metrics_all_subjects = []

# (确保 单元格 2 已运行)
printlog(f"--- 开始在 {DATASET_NAME} 上执行 {DENOISE_METHOD} + {MODEL_TYPE} 受试者内测试 ---", time=True,
         line_break=True)

# 2. --- 主训练循环 (与你之前的一样) ---
for subject in subjects_list:
    for exp_tim in range(1, K_of_repeated_experiments + 1):

        printlog(f"--- 正在处理受试者: {subject} | 实验: {exp_tim}/{K_of_repeated_experiments} ---", time=True, line_break=True)

        test_metrics = train_test_subject(
            subject_id=subject,
            data_dir=DATA_DIR,
            model_denoise=model_denoise,
            device=DEVICE,
            save_dir_models_temp=save_dir_models_temp,
            model_type=MODEL_TYPE,
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            lr=LEARNING_RATE,
            patience=PATIENCE,
            exp_tim=exp_tim
        )

        if test_metrics:
            test_metrics['Experiment'] = exp_tim
            metrics_all_subjects.append(test_metrics)
            print(f"--- 受试者 {subject} 实验 {exp_tim} 完成。最终测试 Acc: {test_metrics['Accuracy']:.2f}% ---")
# --- 主循环结束 ---


printlog(f"--- 所有受试者处理完毕 ---", time=True, line_break=True)

# 3. --- 💡 关键修改：计算并保存为【图片样式】 ---
if metrics_all_subjects:
    # 3.1. 保存【所有50次运行】的详细原始数据
    df_summary = pd.DataFrame(metrics_all_subjects)
    save_path_summary_by_subject = os.path.join(save_dir_root, 'summary_by_subject.csv')
    df_summary.to_csv(save_path_summary_by_subject, index=False, float_format='%.3f')
    print(f"✅ 包含50次运行的详细CSV已保存到: {save_path_summary_by_subject}")

    # 3.2. 计算【每个受试者的平均值】(数字)
    df_avg_by_subject = df_summary.groupby('Subject').mean(numeric_only=True)
    # 计算【每个受试者的标准差】(数字)
    df_std_by_subject = df_summary.groupby('Subject').std(numeric_only=True)

    # 3.3. 创建【受试者10行】的格式化 (mean+std) DataFrame
    df_formatted_subjects = pd.DataFrame(index=df_avg_by_subject.index)

    # 确定要格式化的列 (排除 'Experiment')
    metrics_cols = [col for col in df_avg_by_subject.columns if col != 'Experiment']

    for col in metrics_cols:
        # 格式化为 "均值 + 标准差"，并保留4位小数 (根据图片)
        df_formatted_subjects[col] = df_avg_by_subject[col].map('{:.4f}'.format) + \
                                     "+" + \
                                     df_std_by_subject[col].map('{:.4f}'.format)

    # 3.4. 计算【所有受试者平均值的平均值】(数字)
    df_total_avg = df_avg_by_subject[metrics_cols].mean().to_frame().T

    # 3.5. 计算【所有受试者平均值的标准差】(数字)
    df_total_std = df_avg_by_subject[metrics_cols].std().to_frame().T

    # 3.6. 将总平均值和总标准差格式化为DataFrame (用于拼接)
    # 只保留小数 (根据图片)
    df_total_avg_formatted = df_total_avg.applymap(lambda x: f"{x:.4f}")
    df_total_std_formatted = df_total_std.applymap(lambda x: f"{x:.4f}")

    # 更改索引名以便拼接
    df_total_avg_formatted.index = ['mean']
    df_total_std_formatted.index = ['std']

    # 3.7. 拼接所有部分：10行 (mean+std) + 1行 (total mean) + 1行 (total std)
    df_final_report = pd.concat([df_formatted_subjects, df_total_avg_formatted, df_total_std_formatted])

    # 3.8. 保存最终的报告
    save_path_final_report = os.path.join(save_dir_root, 'all_metrics_averaged_results.csv')
    # index=True 是因为 Subject/mean/std 现在是索引
    df_final_report.to_csv(save_path_final_report, index=True)
    print(f"✅ 【最终报告 (mean+std)】(12行) 已保存到: {save_path_final_report}")

    # (现在 "alone_subject_averaged_results.csv" 已经合并到上面了，不再单独保存)

    # 3.9. 检查 Sub02 (使用未格式化的 df_avg_by_subject)
    try:
        sub02_new_avg = df_avg_by_subject.loc['Sub02']['Accuracy']
        print(f"\n--- 检查 Sub02 ---")
        print(f"Sub02 新的5次实验平均准确率: {sub02_new_avg:.3f}%")
    except Exception as e:
        print(f"无法自动检查 Sub02 的新平均值: {e}")

else:
    print("没有受试者被成功处理。")
# Out:
# ============================================================2025-11-11 19:51:31
# --- 开始在 SIAT 上执行 LD_Net_Online_Classification + SC-BiGRU_FocalLoss_1C 受试者内测试 ---...
#
#
# ============================================================2025-11-11 19:51:31
# --- 正在处理受试者: Sub01 | 实验: 1/5 ---...
#
#   已加载 Sub01: 690 个样本。
# 已实例化 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为分类器设置优化器 (LD-Net 已冻结)...
# Using Adam optimizer, initial learning rate:  0.0005
#   > 使用 AdamW 优化器, lr=0.0005
# Validation loss decreased (inf --> 1.023582).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 51.45% (已保存)
# Validation loss decreased (1.023582 --> 1.000888).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 64.49% (已保存)
# Validation loss decreased (1.000888 --> 0.955851).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 70.29% (已保存)
# Validation loss decreased (0.955851 --> 0.853127).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 71.01% (已保存)
# Validation loss decreased (0.853127 --> 0.716449).  Saving model ...
# Validation loss decreased (0.716449 --> 0.619721).  Saving model ...
# Validation loss decreased (0.619721 --> 0.500193).  Saving model ...
# Validation loss decreased (0.500193 --> 0.440864).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 71.74% (已保存)
# Validation loss decreased (0.440864 --> 0.409349).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 72.46% (已保存)
# Validation loss decreased (0.409349 --> 0.350377).  Saving model ...
# Sub01 | Exp 1 | Ep 010 | Train 0.4664/72.28% | Val 0.3504/72.46%
# EarlyStopping counter: 1 out of 30
#     Sub01 | Exp 1 | 新的最佳准确率: 80.44% (已保存)
# Validation loss decreased (0.350377 --> 0.297325).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 81.88% (已保存)
# EarlyStopping counter: 1 out of 30
#     Sub01 | Exp 1 | 新的最佳准确率: 89.86% (已保存)
# Validation loss decreased (0.297325 --> 0.293925).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 92.75% (已保存)
# Validation loss decreased (0.293925 --> 0.248779).  Saving model ...
# Validation loss decreased (0.248779 --> 0.247218).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 94.93% (已保存)
# Validation loss decreased (0.247218 --> 0.235767).  Saving model ...
# Validation loss decreased (0.235767 --> 0.208500).  Saving model ...
# Validation loss decreased (0.208500 --> 0.193268).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 96.38% (已保存)
# Validation loss decreased (0.193268 --> 0.179989).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 97.10% (已保存)
# Sub01 | Exp 1 | Ep 020 | Train 0.2359/91.85% | Val 0.1800/97.10%
# Validation loss decreased (0.179989 --> 0.164115).  Saving model ...
# Validation loss decreased (0.164115 --> 0.156786).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 98.55% (已保存)
# Validation loss decreased (0.156786 --> 0.141011).  Saving model ...
# Validation loss decreased (0.141011 --> 0.126150).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.126150 --> 0.114943).  Saving model ...
# Validation loss decreased (0.114943 --> 0.108091).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Sub01 | Exp 1 | Ep 030 | Train 0.1634/93.84% | Val 0.1361/92.75%
# Validation loss decreased (0.108091 --> 0.098026).  Saving model ...
# Validation loss decreased (0.098026 --> 0.083131).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Validation loss decreased (0.083131 --> 0.067490).  Saving model ...
# Validation loss decreased (0.067490 --> 0.052992).  Saving model ...
# EarlyStopping counter: 1 out of 30
#     Sub01 | Exp 1 | 新的最佳准确率: 99.28% (已保存)
# Sub01 | Exp 1 | Ep 040 | Train 0.0813/98.01% | Val 0.0568/99.28%
# Validation loss decreased (0.052992 --> 0.051321).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Validation loss decreased (0.051321 --> 0.036399).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.036399 --> 0.032949).  Saving model ...
# Validation loss decreased (0.032949 --> 0.030251).  Saving model ...
# Sub01 | Exp 1 | Ep 050 | Train 0.0590/99.28% | Val 0.0303/99.28%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.030251 --> 0.028763).  Saving model ...
# Validation loss decreased (0.028763 --> 0.028418).  Saving model ...
# Validation loss decreased (0.028418 --> 0.023831).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.023831 --> 0.022667).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.022667 --> 0.020656).  Saving model ...
# Sub01 | Exp 1 | Ep 060 | Train 0.0307/99.64% | Val 0.0207/99.28%
# EarlyStopping counter: 1 out of 30
#     Sub01 | Exp 1 | 新的最佳准确率: 100.00% (已保存)
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.020656 --> 0.019701).  Saving model ...
# Validation loss decreased (0.019701 --> 0.014776).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Sub01 | Exp 1 | Ep 070 | Train 0.0478/97.64% | Val 0.0172/99.28%
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# Validation loss decreased (0.014776 --> 0.014468).  Saving model ...
# Sub01 | Exp 1 | Ep 080 | Train 0.0307/99.46% | Val 0.0145/99.28%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# Sub01 | Exp 1 | Ep 090 | Train 0.0287/99.46% | Val 0.0157/99.28%
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# Sub01 | Exp 1 | Ep 100 | Train 0.0256/99.09% | Val 0.0153/99.28%
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub01 | Exp 1 | Ep 110 | Train 0.0244/100.00% | Val 0.0153/99.28%
# 早停触发 (基于 Val Loss)。
# 加载 Sub01 (Exp 1) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub01\best_acc_model_exp1.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 20  0  0]
#  [ 0  0  0 38  0]
#  [ 0  0  0  0 33]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0. 100.   0.   0.   0.]
#  [  0.   0. 100.   0.   0.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub01
# --- 受试者 Sub01 实验 1 完成。最终测试 Acc: 100.00% ---
#
# ============================================================2025-11-11 19:51:46
# --- 正在处理受试者: Sub01 | 实验: 2/5 ---...
#
#   已加载 Sub01: 690 个样本。
# 已实例化 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为分类器设置优化器 (LD-Net 已冻结)...
# Using Adam optimizer, initial learning rate:  0.0005
#   > 使用 AdamW 优化器, lr=0.0005
# Validation loss decreased (inf --> 1.028249).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 21.01% (已保存)
# Validation loss decreased (1.028249 --> 1.026642).  Saving model ...
# Validation loss decreased (1.026642 --> 1.023318).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 30.43% (已保存)
# Validation loss decreased (1.023318 --> 1.018425).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 39.85% (已保存)
# Validation loss decreased (1.018425 --> 0.973066).  Saving model ...
# Validation loss decreased (0.973066 --> 0.856316).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 55.07% (已保存)
# Validation loss decreased (0.856316 --> 0.654054).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 73.19% (已保存)
# Validation loss decreased (0.654054 --> 0.509605).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 74.64% (已保存)
# Validation loss decreased (0.509605 --> 0.434090).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 78.26% (已保存)
# Validation loss decreased (0.434090 --> 0.386450).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 78.99% (已保存)
# Sub01 | Exp 2 | Ep 010 | Train 0.4439/85.51% | Val 0.3864/78.99%
# Validation loss decreased (0.386450 --> 0.366816).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 79.71% (已保存)
# Validation loss decreased (0.366816 --> 0.323338).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 81.88% (已保存)
# Validation loss decreased (0.323338 --> 0.306314).  Saving model ...
# Validation loss decreased (0.306314 --> 0.255744).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 84.78% (已保存)
# Validation loss decreased (0.255744 --> 0.253758).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 95.65% (已保存)
# Validation loss decreased (0.253758 --> 0.233308).  Saving model ...
# Validation loss decreased (0.233308 --> 0.162061).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 100.00% (已保存)
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.162061 --> 0.149692).  Saving model ...
# Validation loss decreased (0.149692 --> 0.133377).  Saving model ...
# Sub01 | Exp 2 | Ep 020 | Train 0.2044/97.46% | Val 0.1334/100.00%
# Validation loss decreased (0.133377 --> 0.129449).  Saving model ...
# Validation loss decreased (0.129449 --> 0.123908).  Saving model ...
# Validation loss decreased (0.123908 --> 0.100147).  Saving model ...
# Validation loss decreased (0.100147 --> 0.088549).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.088549 --> 0.071362).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.071362 --> 0.068656).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.068656 --> 0.056569).  Saving model ...
# Sub01 | Exp 2 | Ep 030 | Train 0.0846/99.46% | Val 0.0566/99.28%
# Validation loss decreased (0.056569 --> 0.048558).  Saving model ...
# Validation loss decreased (0.048558 --> 0.046236).  Saving model ...
# Validation loss decreased (0.046236 --> 0.041710).  Saving model ...
# Validation loss decreased (0.041710 --> 0.039023).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Validation loss decreased (0.039023 --> 0.029158).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Sub01 | Exp 2 | Ep 040 | Train 0.0666/98.37% | Val 0.0338/99.28%
# Validation loss decreased (0.029158 --> 0.027934).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.027934 --> 0.025801).  Saving model ...
# Validation loss decreased (0.025801 --> 0.023666).  Saving model ...
# Validation loss decreased (0.023666 --> 0.023044).  Saving model ...
# Validation loss decreased (0.023044 --> 0.017944).  Saving model ...
# Validation loss decreased (0.017944 --> 0.016706).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Sub01 | Exp 2 | Ep 050 | Train 0.0412/99.64% | Val 0.0195/99.28%
# EarlyStopping counter: 4 out of 30
# Validation loss decreased (0.016706 --> 0.014662).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# Sub01 | Exp 2 | Ep 060 | Train 0.0294/99.82% | Val 0.0178/99.28%
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# Sub01 | Exp 2 | Ep 070 | Train 0.0271/99.82% | Val 0.0169/99.28%
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# Sub01 | Exp 2 | Ep 080 | Train 0.0307/99.28% | Val 0.0176/99.28%
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub01 | Exp 2 | Ep 082 | Train 0.0335/99.46% | Val 0.0173/99.28%
# 早停触发 (基于 Val Loss)。
# 加载 Sub01 (Exp 2) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub01\best_acc_model_exp2.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 20  0  0]
#  [ 0  0  0 38  0]
#  [ 0  0  0  0 33]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0. 100.   0.   0.   0.]
#  [  0.   0. 100.   0.   0.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub01
# --- 受试者 Sub01 实验 2 完成。最终测试 Acc: 100.00% ---
#
# ============================================================2025-11-11 19:51:56
# --- 正在处理受试者: Sub01 | 实验: 3/5 ---...
#
#   已加载 Sub01: 690 个样本。
# 已实例化 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为分类器设置优化器 (LD-Net 已冻结)...
# Using Adam optimizer, initial learning rate:  0.0005
#   > 使用 AdamW 优化器, lr=0.0005
# Validation loss decreased (inf --> 1.023975).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 51.45% (已保存)
# Validation loss decreased (1.023975 --> 1.012814).  Saving model ...
# Validation loss decreased (1.012814 --> 0.988545).  Saving model ...
# Validation loss decreased (0.988545 --> 0.850875).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 59.42% (已保存)
# Validation loss decreased (0.850875 --> 0.717826).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 70.29% (已保存)
# Validation loss decreased (0.717826 --> 0.588346).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 71.74% (已保存)
# Validation loss decreased (0.588346 --> 0.505646).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 72.46% (已保存)
# Validation loss decreased (0.505646 --> 0.440930).  Saving model ...
# Validation loss decreased (0.440930 --> 0.427207).  Saving model ...
# Validation loss decreased (0.427207 --> 0.379304).  Saving model ...
# Sub01 | Exp 3 | Ep 010 | Train 0.4550/71.74% | Val 0.3793/72.46%
# Validation loss decreased (0.379304 --> 0.342052).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 84.78% (已保存)
# Validation loss decreased (0.342052 --> 0.297543).  Saving model ...
# Validation loss decreased (0.297543 --> 0.276156).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 93.48% (已保存)
# Validation loss decreased (0.276156 --> 0.259276).  Saving model ...
# Validation loss decreased (0.259276 --> 0.230127).  Saving model ...
# Validation loss decreased (0.230127 --> 0.217546).  Saving model ...
# Validation loss decreased (0.217546 --> 0.195507).  Saving model ...
# Validation loss decreased (0.195507 --> 0.173260).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 94.20% (已保存)
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.173260 --> 0.157261).  Saving model ...
# Sub01 | Exp 3 | Ep 020 | Train 0.2186/94.93% | Val 0.1573/92.75%
# Validation loss decreased (0.157261 --> 0.145973).  Saving model ...
# Validation loss decreased (0.145973 --> 0.145472).  Saving model ...
# Validation loss decreased (0.145472 --> 0.130476).  Saving model ...
# Validation loss decreased (0.130476 --> 0.126239).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.126239 --> 0.110478).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.110478 --> 0.097246).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Sub01 | Exp 3 | Ep 030 | Train 0.1222/95.83% | Val 0.1001/93.48%
# Validation loss decreased (0.097246 --> 0.096769).  Saving model ...
# Validation loss decreased (0.096769 --> 0.080887).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# Sub01 | Exp 3 | Ep 040 | Train 0.0622/99.64% | Val 0.0906/91.30%
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# Sub01 | Exp 3 | Ep 050 | Train 0.0608/99.82% | Val 0.0894/92.03%
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# Sub01 | Exp 3 | Ep 060 | Train 0.0580/99.28% | Val 0.0903/91.30%
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub01 | Exp 3 | Ep 062 | Train 0.0591/99.64% | Val 0.0896/92.03%
# 早停触发 (基于 Val Loss)。
# 加载 Sub01 (Exp 3) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub01\best_acc_model_exp3.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 20  0  0]
#  [ 1  0  0 37  0]
#  [ 0  0  7  0 26]]
# Normalized Confusion Matrix:
# [[100.           0.           0.           0.           0.        ]
#  [  0.         100.           0.           0.           0.        ]
#  [  0.           0.         100.           0.           0.        ]
#  [  2.63157895   0.           0.          97.36842105   0.        ]
#  [  0.           0.          21.21212121   0.          78.78787879]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub01
# --- 受试者 Sub01 实验 3 完成。最终测试 Acc: 94.20% ---
#
# ============================================================2025-11-11 19:52:03
# --- 正在处理受试者: Sub01 | 实验: 4/5 ---...
#
#   已加载 Sub01: 690 个样本。
# 已实例化 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为分类器设置优化器 (LD-Net 已冻结)...
# Using Adam optimizer, initial learning rate:  0.0005
#   > 使用 AdamW 优化器, lr=0.0005
# Validation loss decreased (inf --> 1.027613).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 45.65% (已保存)
# Validation loss decreased (1.027613 --> 1.021656).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 47.10% (已保存)
# Validation loss decreased (1.021656 --> 1.004216).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 52.17% (已保存)
# Validation loss decreased (1.004216 --> 0.934655).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 71.01% (已保存)
# Validation loss decreased (0.934655 --> 0.818196).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 72.46% (已保存)
# Validation loss decreased (0.818196 --> 0.628138).  Saving model ...
# Validation loss decreased (0.628138 --> 0.532094).  Saving model ...
# Validation loss decreased (0.532094 --> 0.425790).  Saving model ...
# Validation loss decreased (0.425790 --> 0.405717).  Saving model ...
# Validation loss decreased (0.405717 --> 0.370355).  Saving model ...
# Sub01 | Exp 4 | Ep 010 | Train 0.4384/72.10% | Val 0.3704/72.46%
# Validation loss decreased (0.370355 --> 0.339426).  Saving model ...
# Validation loss decreased (0.339426 --> 0.325521).  Saving model ...
# Validation loss decreased (0.325521 --> 0.310470).  Saving model ...
# Validation loss decreased (0.310470 --> 0.300544).  Saving model ...
# Validation loss decreased (0.300544 --> 0.293664).  Saving model ...
# Validation loss decreased (0.293664 --> 0.275253).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 85.51% (已保存)
# EarlyStopping counter: 1 out of 30
#     Sub01 | Exp 4 | 新的最佳准确率: 86.96% (已保存)
# Validation loss decreased (0.275253 --> 0.269529).  Saving model ...
# Validation loss decreased (0.269529 --> 0.247230).  Saving model ...
# Validation loss decreased (0.247230 --> 0.238953).  Saving model ...
# Sub01 | Exp 4 | Ep 020 | Train 0.2751/85.87% | Val 0.2390/86.23%
# Validation loss decreased (0.238953 --> 0.226906).  Saving model ...
# Validation loss decreased (0.226906 --> 0.216534).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.216534 --> 0.209679).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 89.86% (已保存)
# Validation loss decreased (0.209679 --> 0.205940).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 98.55% (已保存)
# Validation loss decreased (0.205940 --> 0.204206).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 100.00% (已保存)
# Validation loss decreased (0.204206 --> 0.203650).  Saving model ...
# Validation loss decreased (0.203650 --> 0.191619).  Saving model ...
# Validation loss decreased (0.191619 --> 0.187852).  Saving model ...
# Validation loss decreased (0.187852 --> 0.182961).  Saving model ...
# Sub01 | Exp 4 | Ep 030 | Train 0.2197/96.56% | Val 0.1830/100.00%
# Validation loss decreased (0.182961 --> 0.178548).  Saving model ...
# Validation loss decreased (0.178548 --> 0.170921).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.170921 --> 0.170227).  Saving model ...
# Validation loss decreased (0.170227 --> 0.159405).  Saving model ...
# Validation loss decreased (0.159405 --> 0.159399).  Saving model ...
# Validation loss decreased (0.159399 --> 0.154807).  Saving model ...
# Validation loss decreased (0.154807 --> 0.151268).  Saving model ...
# Validation loss decreased (0.151268 --> 0.145122).  Saving model ...
# Validation loss decreased (0.145122 --> 0.141749).  Saving model ...
# Sub01 | Exp 4 | Ep 040 | Train 0.1684/98.91% | Val 0.1417/100.00%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.141749 --> 0.138254).  Saving model ...
# Validation loss decreased (0.138254 --> 0.135105).  Saving model ...
# Validation loss decreased (0.135105 --> 0.135024).  Saving model ...
# Validation loss decreased (0.135024 --> 0.133491).  Saving model ...
# Validation loss decreased (0.133491 --> 0.128581).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.128581 --> 0.127680).  Saving model ...
# Validation loss decreased (0.127680 --> 0.125244).  Saving model ...
# Sub01 | Exp 4 | Ep 050 | Train 0.1455/98.37% | Val 0.1252/100.00%
# Validation loss decreased (0.125244 --> 0.122624).  Saving model ...
# Validation loss decreased (0.122624 --> 0.121119).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.121119 --> 0.117430).  Saving model ...
# Validation loss decreased (0.117430 --> 0.115362).  Saving model ...
# Validation loss decreased (0.115362 --> 0.115089).  Saving model ...
# Validation loss decreased (0.115089 --> 0.114985).  Saving model ...
# Validation loss decreased (0.114985 --> 0.113249).  Saving model ...
# Validation loss decreased (0.113249 --> 0.112835).  Saving model ...
# Validation loss decreased (0.112835 --> 0.110447).  Saving model ...
# Sub01 | Exp 4 | Ep 060 | Train 0.1257/99.28% | Val 0.1104/100.00%
# Validation loss decreased (0.110447 --> 0.108949).  Saving model ...
# Validation loss decreased (0.108949 --> 0.108414).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.108414 --> 0.106117).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.106117 --> 0.104415).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Sub01 | Exp 4 | Ep 070 | Train 0.1273/98.01% | Val 0.1130/98.55%
# Validation loss decreased (0.104415 --> 0.102629).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.102629 --> 0.097587).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.097587 --> 0.095231).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Sub01 | Exp 4 | Ep 080 | Train 0.1117/99.28% | Val 0.1055/99.28%
# Validation loss decreased (0.095231 --> 0.094025).  Saving model ...
# Validation loss decreased (0.094025 --> 0.090581).  Saving model ...
# Validation loss decreased (0.090581 --> 0.089717).  Saving model ...
# Validation loss decreased (0.089717 --> 0.089385).  Saving model ...
# Validation loss decreased (0.089385 --> 0.088356).  Saving model ...
# Validation loss decreased (0.088356 --> 0.087480).  Saving model ...
# Validation loss decreased (0.087480 --> 0.086603).  Saving model ...
# Validation loss decreased (0.086603 --> 0.086530).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.086530 --> 0.086444).  Saving model ...
# Sub01 | Exp 4 | Ep 090 | Train 0.0894/99.64% | Val 0.0864/100.00%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.086444 --> 0.086333).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.086333 --> 0.081400).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.081400 --> 0.079611).  Saving model ...
# Validation loss decreased (0.079611 --> 0.078700).  Saving model ...
# Validation loss decreased (0.078700 --> 0.077989).  Saving model ...
# Validation loss decreased (0.077989 --> 0.077614).  Saving model ...
# Sub01 | Exp 4 | Ep 100 | Train 0.0830/99.82% | Val 0.0776/100.00%
# Validation loss decreased (0.077614 --> 0.076850).  Saving model ...
# Validation loss decreased (0.076850 --> 0.075921).  Saving model ...
# Validation loss decreased (0.075921 --> 0.075265).  Saving model ...
# Validation loss decreased (0.075265 --> 0.074828).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Validation loss decreased (0.074828 --> 0.071629).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Sub01 | Exp 4 | Ep 110 | Train 0.0955/98.91% | Val 0.0727/100.00%
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Validation loss decreased (0.071629 --> 0.070171).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.070171 --> 0.068733).  Saving model ...
# Validation loss decreased (0.068733 --> 0.068327).  Saving model ...
# Validation loss decreased (0.068327 --> 0.067642).  Saving model ...
# Validation loss decreased (0.067642 --> 0.067453).  Saving model ...
# Sub01 | Exp 4 | Ep 120 | Train 0.0679/100.00% | Val 0.0675/100.00%
# Validation loss decreased (0.067453 --> 0.065543).  Saving model ...
# Validation loss decreased (0.065543 --> 0.064538).  Saving model ...
# Validation loss decreased (0.064538 --> 0.064384).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Validation loss decreased (0.064384 --> 0.063317).  Saving model ...
# Validation loss decreased (0.063317 --> 0.061229).  Saving model ...
# Validation loss decreased (0.061229 --> 0.060927).  Saving model ...
# Sub01 | Exp 4 | Ep 130 | Train 0.0655/100.00% | Val 0.0609/100.00%
# Validation loss decreased (0.060927 --> 0.060003).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.060003 --> 0.058773).  Saving model ...
# Validation loss decreased (0.058773 --> 0.057483).  Saving model ...
# Validation loss decreased (0.057483 --> 0.056943).  Saving model ...
# Validation loss decreased (0.056943 --> 0.056674).  Saving model ...
# Validation loss decreased (0.056674 --> 0.056100).  Saving model ...
# Validation loss decreased (0.056100 --> 0.055720).  Saving model ...
# Validation loss decreased (0.055720 --> 0.055275).  Saving model ...
# Sub01 | Exp 4 | Ep 140 | Train 0.0602/99.82% | Val 0.0553/100.00%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.055275 --> 0.054795).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Validation loss decreased (0.054795 --> 0.053424).  Saving model ...
# Validation loss decreased (0.053424 --> 0.051474).  Saving model ...
# Sub01 | Exp 4 | Ep 150 | Train 0.0521/100.00% | Val 0.0515/100.00%
# Validation loss decreased (0.051474 --> 0.050116).  Saving model ...
# Validation loss decreased (0.050116 --> 0.049747).  Saving model ...
# Validation loss decreased (0.049747 --> 0.049321).  Saving model ...
# Validation loss decreased (0.049321 --> 0.049032).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Validation loss decreased (0.049032 --> 0.048208).  Saving model ...
# Sub01 | Exp 4 | Ep 160 | Train 0.0490/100.00% | Val 0.0482/100.00%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.048208 --> 0.046891).  Saving model ...
# Validation loss decreased (0.046891 --> 0.045768).  Saving model ...
# Validation loss decreased (0.045768 --> 0.045634).  Saving model ...
# Validation loss decreased (0.045634 --> 0.044864).  Saving model ...
# Validation loss decreased (0.044864 --> 0.044520).  Saving model ...
# Validation loss decreased (0.044520 --> 0.044209).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.044209 --> 0.042840).  Saving model ...
# Sub01 | Exp 4 | Ep 170 | Train 0.0463/100.00% | Val 0.0428/100.00%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.042840 --> 0.041928).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.041928 --> 0.040247).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Sub01 | Exp 4 | Ep 180 | Train 0.0432/99.82% | Val 0.0413/99.28%
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Validation loss decreased (0.040247 --> 0.038503).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Validation loss decreased (0.038503 --> 0.037292).  Saving model ...
# Validation loss decreased (0.037292 --> 0.036891).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Sub01 | Exp 4 | Ep 190 | Train 0.0369/100.00% | Val 0.0370/100.00%
# Validation loss decreased (0.036891 --> 0.035901).  Saving model ...
# Validation loss decreased (0.035901 --> 0.035634).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.035634 --> 0.034377).  Saving model ...
# Validation loss decreased (0.034377 --> 0.034026).  Saving model ...
# Validation loss decreased (0.034026 --> 0.033951).  Saving model ...
# Validation loss decreased (0.033951 --> 0.033834).  Saving model ...
# Validation loss decreased (0.033834 --> 0.033423).  Saving model ...
# Sub01 | Exp 4 | Ep 200 | Train 0.0357/99.82% | Val 0.0334/100.00%
# 加载 Sub01 (Exp 4) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub01\best_acc_model_exp4.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 20  0  0]
#  [ 0  0  0 38  0]
#  [ 0  0  0  0 33]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0. 100.   0.   0.   0.]
#  [  0.   0. 100.   0.   0.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub01
# --- 受试者 Sub01 实验 4 完成。最终测试 Acc: 100.00% ---
#
# ============================================================2025-11-11 19:52:26
# --- 正在处理受试者: Sub01 | 实验: 5/5 ---...
#
#   已加载 Sub01: 690 个样本。
# 已实例化 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为分类器设置优化器 (LD-Net 已冻结)...
# Using Adam optimizer, initial learning rate:  0.0005
#   > 使用 AdamW 优化器, lr=0.0005
# Validation loss decreased (inf --> 1.027644).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 50.73% (已保存)
# Validation loss decreased (1.027644 --> 1.015428).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 72.46% (已保存)
# Validation loss decreased (1.015428 --> 0.969419).  Saving model ...
# Validation loss decreased (0.969419 --> 0.858952).  Saving model ...
# Validation loss decreased (0.858952 --> 0.697887).  Saving model ...
# Validation loss decreased (0.697887 --> 0.520250).  Saving model ...
# Validation loss decreased (0.520250 --> 0.432191).  Saving model ...
# Validation loss decreased (0.432191 --> 0.379539).  Saving model ...
# Validation loss decreased (0.379539 --> 0.304018).  Saving model ...
# Validation loss decreased (0.304018 --> 0.287187).  Saving model ...
# Sub01 | Exp 5 | Ep 010 | Train 0.4123/75.00% | Val 0.2872/72.46%
# Validation loss decreased (0.287187 --> 0.282270).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 74.64% (已保存)
# Validation loss decreased (0.282270 --> 0.258987).  Saving model ...
# Validation loss decreased (0.258987 --> 0.225219).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 90.58% (已保存)
# Validation loss decreased (0.225219 --> 0.210211).  Saving model ...
# Validation loss decreased (0.210211 --> 0.198055).  Saving model ...
# Validation loss decreased (0.198055 --> 0.183529).  Saving model ...
# Validation loss decreased (0.183529 --> 0.173462).  Saving model ...
# EarlyStopping counter: 1 out of 30
#     Sub01 | Exp 5 | 新的最佳准确率: 99.28% (已保存)
# Validation loss decreased (0.173462 --> 0.143683).  Saving model ...
# Validation loss decreased (0.143683 --> 0.140988).  Saving model ...
# Sub01 | Exp 5 | Ep 020 | Train 0.2075/95.29% | Val 0.1410/92.75%
# Validation loss decreased (0.140988 --> 0.123139).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.123139 --> 0.106958).  Saving model ...
# Validation loss decreased (0.106958 --> 0.097055).  Saving model ...
# Validation loss decreased (0.097055 --> 0.094729).  Saving model ...
# Validation loss decreased (0.094729 --> 0.087917).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.087917 --> 0.065373).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.065373 --> 0.059349).  Saving model ...
# Sub01 | Exp 5 | Ep 030 | Train 0.0927/99.46% | Val 0.0593/99.28%
# Validation loss decreased (0.059349 --> 0.056384).  Saving model ...
# Validation loss decreased (0.056384 --> 0.051807).  Saving model ...
# Validation loss decreased (0.051807 --> 0.044399).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.044399 --> 0.035417).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.035417 --> 0.028099).  Saving model ...
# Validation loss decreased (0.028099 --> 0.026625).  Saving model ...
# Sub01 | Exp 5 | Ep 040 | Train 0.0657/98.73% | Val 0.0266/99.28%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.026625 --> 0.024932).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.024932 --> 0.019483).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Sub01 | Exp 5 | Ep 050 | Train 0.0410/99.64% | Val 0.0200/99.28%
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# Sub01 | Exp 5 | Ep 060 | Train 0.0332/99.64% | Val 0.0213/99.28%
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# Validation loss decreased (0.019483 --> 0.018800).  Saving model ...
# Sub01 | Exp 5 | Ep 070 | Train 0.0351/100.00% | Val 0.0188/99.28%
# Validation loss decreased (0.018800 --> 0.018477).  Saving model ...
# Validation loss decreased (0.018477 --> 0.017962).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# Sub01 | Exp 5 | Ep 080 | Train 0.0378/99.82% | Val 0.0204/99.28%
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# Sub01 | Exp 5 | Ep 090 | Train 0.0497/98.91% | Val 0.0193/99.28%
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# Sub01 | Exp 5 | Ep 100 | Train 0.0443/99.46% | Val 0.0209/99.28%
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub01 | Exp 5 | Ep 102 | Train 0.0319/100.00% | Val 0.0194/99.28%
# 早停触发 (基于 Val Loss)。
# 加载 Sub01 (Exp 5) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub01\best_acc_model_exp5.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 19  0  1]
#  [ 0  0  0 38  0]
#  [ 0  0  0  0 33]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0. 100.   0.   0.   0.]
#  [  0.   0.  95.   0.   5.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub01
# --- 受试者 Sub01 实验 5 完成。最终测试 Acc: 99.28% ---
#
# ============================================================2025-11-11 19:52:38
# --- 正在处理受试者: Sub02 | 实验: 1/5 ---...
#
#   已加载 Sub02: 483 个样本。
# 已实例化 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为分类器设置优化器 (LD-Net 已冻结)...
# Using Adam optimizer, initial learning rate:  0.0005
#   > 使用 AdamW 优化器, lr=0.0005
# Validation loss decreased (inf --> 1.026432).  Saving model ...
#     Sub02 | Exp 1 | 新的最佳准确率: 41.24% (已保存)
# Validation loss decreased (1.026432 --> 1.013420).  Saving model ...
# Validation loss decreased (1.013420 --> 0.985198).  Saving model ...
# Validation loss decreased (0.985198 --> 0.939989).  Saving model ...
# Validation loss decreased (0.939989 --> 0.900038).  Saving model ...
# Validation loss decreased (0.900038 --> 0.810542).  Saving model ...
#     Sub02 | Exp 1 | 新的最佳准确率: 54.64% (已保存)
# Validation loss decreased (0.810542 --> 0.722724).  Saving model ...
#     Sub02 | Exp 1 | 新的最佳准确率: 75.26% (已保存)
# Validation loss decreased (0.722724 --> 0.648174).  Saving model ...
# Validation loss decreased (0.648174 --> 0.594328).  Saving model ...
# Validation loss decreased (0.594328 --> 0.563608).  Saving model ...
# Sub02 | Exp 1 | Ep 010 | Train 0.6150/62.69% | Val 0.5636/63.92%
# Validation loss decreased (0.563608 --> 0.536465).  Saving model ...
# Validation loss decreased (0.536465 --> 0.482130).  Saving model ...
# Validation loss decreased (0.482130 --> 0.470586).  Saving model ...
# Validation loss decreased (0.470586 --> 0.434161).  Saving model ...
# Validation loss decreased (0.434161 --> 0.412139).  Saving model ...
# Validation loss decreased (0.412139 --> 0.404664).  Saving model ...
# Validation loss decreased (0.404664 --> 0.403884).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.403884 --> 0.381447).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Sub02 | Exp 1 | Ep 020 | Train 0.3934/64.25% | Val 0.3936/64.95%
# Validation loss decreased (0.381447 --> 0.372432).  Saving model ...
# Validation loss decreased (0.372432 --> 0.334068).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.334068 --> 0.294175).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# Sub02 | Exp 1 | Ep 030 | Train 0.3061/63.73% | Val 0.3007/64.95%
# Validation loss decreased (0.294175 --> 0.286551).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# Validation loss decreased (0.286551 --> 0.283933).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Sub02 | Exp 1 | Ep 040 | Train 0.3035/63.47% | Val 0.2998/64.95%
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# Validation loss decreased (0.283933 --> 0.283622).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.283622 --> 0.283482).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.283482 --> 0.277935).  Saving model ...
# Sub02 | Exp 1 | Ep 050 | Train 0.3106/62.69% | Val 0.2779/64.95%
# Validation loss decreased (0.277935 --> 0.275290).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# Sub02 | Exp 1 | Ep 060 | Train 0.3165/63.73% | Val 0.2814/64.95%
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# Validation loss decreased (0.275290 --> 0.271808).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Sub02 | Exp 1 | Ep 070 | Train 0.3101/63.73% | Val 0.2745/64.95%
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# Validation loss decreased (0.271808 --> 0.265528).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# Sub02 | Exp 1 | Ep 080 | Train 0.3012/62.95% | Val 0.3079/64.95%
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# Sub02 | Exp 1 | Ep 090 | Train 0.3094/63.73% | Val 0.2969/64.95%
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# Sub02 | Exp 1 | Ep 100 | Train 0.3026/64.25% | Val 0.2986/64.95%
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub02 | Exp 1 | Ep 104 | Train 0.3037/63.73% | Val 0.2943/64.95%
# 早停触发 (基于 Val Loss)。
# 加载 Sub02 (Exp 1) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub02\best_acc_model_exp1.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[ 0  0  0 22  0]
#  [ 0 12  0  0  0]
#  [ 0  2 11  0  0]
#  [ 0  0  0 28  0]
#  [ 0  0  0  0 22]]
# Normalized Confusion Matrix:
# [[  0.           0.           0.         100.           0.        ]
#  [  0.         100.           0.           0.           0.        ]
#  [  0.          15.38461538  84.61538462   0.           0.        ]
#  [  0.           0.           0.         100.           0.        ]
#  [  0.           0.           0.           0.         100.        ]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub02
# --- 受试者 Sub02 实验 1 完成。最终测试 Acc: 75.26% ---
#
# ============================================================2025-11-11 19:52:47
# --- 正在处理受试者: Sub02 | 实验: 2/5 ---...
#
#   已加载 Sub02: 483 个样本。
# 已实例化 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为分类器设置优化器 (LD-Net 已冻结)...
# Using Adam optimizer, initial learning rate:  0.0005
#   > 使用 AdamW 优化器, lr=0.0005
# Validation loss decreased (inf --> 1.027733).  Saving model ...
#     Sub02 | Exp 2 | 新的最佳准确率: 28.87% (已保存)
# Validation loss decreased (1.027733 --> 1.019790).  Saving model ...
#     Sub02 | Exp 2 | 新的最佳准确率: 51.55% (已保存)
# Validation loss decreased (1.019790 --> 1.000957).  Saving model ...
#     Sub02 | Exp 2 | 新的最佳准确率: 65.98% (已保存)
# Validation loss decreased (1.000957 --> 0.971802).  Saving model ...
# Validation loss decreased (0.971802 --> 0.921217).  Saving model ...
# Validation loss decreased (0.921217 --> 0.844954).  Saving model ...
# Validation loss decreased (0.844954 --> 0.751017).  Saving model ...
# Validation loss decreased (0.751017 --> 0.710526).  Saving model ...
#     Sub02 | Exp 2 | 新的最佳准确率: 67.01% (已保存)
# Validation loss decreased (0.710526 --> 0.621420).  Saving model ...
# Validation loss decreased (0.621420 --> 0.607001).  Saving model ...
# Sub02 | Exp 2 | Ep 010 | Train 0.6046/64.25% | Val 0.6070/62.89%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.607001 --> 0.527016).  Saving model ...
# Validation loss decreased (0.527016 --> 0.513538).  Saving model ...
# Validation loss decreased (0.513538 --> 0.422370).  Saving model ...
# ...
# Sub35 | Exp 2 | Ep 030 | Train 0.1680/86.61% | Val 0.2682/80.56%
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# Sub35 | Exp 2 | Ep 040 | Train 0.1525/88.70% | Val 0.4028/67.36%
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# Sub35 | Exp 2 | Ep 050 | Train 0.1504/89.22% | Val 0.3862/68.75%
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub35 | Exp 2 | Ep 052 | Train 0.1592/88.52% | Val 0.3971/67.36%
# 早停触发 (基于 Val Loss)。
# 加载 Sub35 (Exp 2) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub35\best_acc_model_exp2.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[28  0  0  0  0]
#  [ 0  0  0  0 11]
#  [ 0  0  0 11  0]
#  [ 0  0  0 42  0]
#  [ 0  0  0  0 52]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0.   0.   0.   0. 100.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub35
# --- 受试者 Sub35 实验 2 完成。最终测试 Acc: 84.72% ---
#
# ============================================================2025-11-11 19:58:48
# --- 正在处理受试者: Sub35 | 实验: 3/5 ---...
#
#   已加载 Sub35: 719 个样本。
# 已实例化 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为分类器设置优化器 (LD-Net 已冻结)...
# Using Adam optimizer, initial learning rate:  0.0005
#   > 使用 AdamW 优化器, lr=0.0005
# Validation loss decreased (inf --> 1.025765).  Saving model ...
#     Sub35 | Exp 3 | 新的最佳准确率: 38.19% (已保存)
# Validation loss decreased (1.025765 --> 1.008534).  Saving model ...
#     Sub35 | Exp 3 | 新的最佳准确率: 81.25% (已保存)
# Validation loss decreased (1.008534 --> 0.963108).  Saving model ...
# Validation loss decreased (0.963108 --> 0.847111).  Saving model ...
#     Sub35 | Exp 3 | 新的最佳准确率: 83.33% (已保存)
# Validation loss decreased (0.847111 --> 0.686759).  Saving model ...
# Validation loss decreased (0.686759 --> 0.524777).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.524777 --> 0.400323).  Saving model ...
# Validation loss decreased (0.400323 --> 0.399614).  Saving model ...
# Validation loss decreased (0.399614 --> 0.323042).  Saving model ...
# Sub35 | Exp 3 | Ep 010 | Train 0.3801/84.87% | Val 0.3230/83.33%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Validation loss decreased (0.323042 --> 0.294419).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Sub35 | Exp 3 | Ep 020 | Train 0.1692/89.22% | Val 0.3633/72.92%
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# Sub35 | Exp 3 | Ep 030 | Train 0.1556/93.22% | Val 0.4206/70.83%
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# Sub35 | Exp 3 | Ep 040 | Train 0.1381/95.48% | Val 0.4332/69.44%
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub35 | Exp 3 | Ep 045 | Train 0.1438/93.74% | Val 0.4151/71.53%
# 早停触发 (基于 Val Loss)。
# 加载 Sub35 (Exp 3) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub35\best_acc_model_exp3.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[28  0  0  0  0]
#  [ 0  0  0  0 11]
#  [ 0  0  0 11  0]
#  [ 0  0  0 40  2]
#  [ 0  0  0  0 52]]
# Normalized Confusion Matrix:
# [[100.           0.           0.           0.           0.        ]
#  [  0.           0.           0.           0.         100.        ]
#  [  0.           0.           0.         100.           0.        ]
#  [  0.           0.           0.          95.23809524   4.76190476]
#  [  0.           0.           0.           0.         100.        ]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub35
# --- 受试者 Sub35 实验 3 完成。最终测试 Acc: 83.33% ---
#
# ============================================================2025-11-11 19:58:53
# --- 正在处理受试者: Sub35 | 实验: 4/5 ---...
#
#   已加载 Sub35: 719 个样本。
# 已实例化 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为分类器设置优化器 (LD-Net 已冻结)...
# Using Adam optimizer, initial learning rate:  0.0005
#   > 使用 AdamW 优化器, lr=0.0005
# Validation loss decreased (inf --> 1.024643).  Saving model ...
#     Sub35 | Exp 4 | 新的最佳准确率: 64.58% (已保存)
# Validation loss decreased (1.024643 --> 1.009803).  Saving model ...
#     Sub35 | Exp 4 | 新的最佳准确率: 77.78% (已保存)
# Validation loss decreased (1.009803 --> 0.974035).  Saving model ...
# Validation loss decreased (0.974035 --> 0.881792).  Saving model ...
# Validation loss decreased (0.881792 --> 0.740599).  Saving model ...
# Validation loss decreased (0.740599 --> 0.554218).  Saving model ...
#     Sub35 | Exp 4 | 新的最佳准确率: 84.72% (已保存)
# Validation loss decreased (0.554218 --> 0.460329).  Saving model ...
# Validation loss decreased (0.460329 --> 0.416992).  Saving model ...
# Validation loss decreased (0.416992 --> 0.409666).  Saving model ...
# Validation loss decreased (0.409666 --> 0.335715).  Saving model ...
# Sub35 | Exp 4 | Ep 010 | Train 0.4102/84.70% | Val 0.3357/84.03%
# Validation loss decreased (0.335715 --> 0.335538).  Saving model ...
# Validation loss decreased (0.335538 --> 0.306498).  Saving model ...
# Validation loss decreased (0.306498 --> 0.280438).  Saving model ...
# Validation loss decreased (0.280438 --> 0.254979).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.254979 --> 0.232904).  Saving model ...
# Validation loss decreased (0.232904 --> 0.223690).  Saving model ...
# Validation loss decreased (0.223690 --> 0.219546).  Saving model ...
# Validation loss decreased (0.219546 --> 0.208168).  Saving model ...
# Validation loss decreased (0.208168 --> 0.197292).  Saving model ...
# Sub35 | Exp 4 | Ep 020 | Train 0.1985/84.70% | Val 0.1973/84.72%
# Validation loss decreased (0.197292 --> 0.187704).  Saving model ...
# Validation loss decreased (0.187704 --> 0.185214).  Saving model ...
#     Sub35 | Exp 4 | 新的最佳准确率: 85.42% (已保存)
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.185214 --> 0.167430).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.167430 --> 0.157556).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.157556 --> 0.151517).  Saving model ...
# EarlyStopping counter: 1 out of 30
#     Sub35 | Exp 4 | 新的最佳准确率: 91.67% (已保存)
# Sub35 | Exp 4 | Ep 030 | Train 0.1330/90.26% | Val 0.1561/91.67%
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.151517 --> 0.151007).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.151007 --> 0.124524).  Saving model ...
# EarlyStopping counter: 1 out of 30
#     Sub35 | Exp 4 | 新的最佳准确率: 92.36% (已保存)
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Validation loss decreased (0.124524 --> 0.115426).  Saving model ...
# Sub35 | Exp 4 | Ep 040 | Train 0.1034/92.17% | Val 0.1154/92.36%
# EarlyStopping counter: 1 out of 30
#     Sub35 | Exp 4 | 新的最佳准确率: 98.61% (已保存)
# EarlyStopping counter: 2 out of 30
#     Sub35 | Exp 4 | 新的最佳准确率: 99.31% (已保存)
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
#     Sub35 | Exp 4 | 新的最佳准确率: 100.00% (已保存)
# Validation loss decreased (0.115426 --> 0.105861).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Sub35 | Exp 4 | Ep 050 | Train 0.0930/99.65% | Val 0.1438/99.31%
# Validation loss decreased (0.105861 --> 0.105573).  Saving model ...
# Validation loss decreased (0.105573 --> 0.103721).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.103721 --> 0.101676).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.101676 --> 0.092469).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Sub35 | Exp 4 | Ep 060 | Train 0.0828/99.30% | Val 0.0950/100.00%
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# Sub35 | Exp 4 | Ep 070 | Train 0.0813/99.13% | Val 0.1139/99.31%
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# Sub35 | Exp 4 | Ep 080 | Train 0.0749/99.83% | Val 0.1142/99.31%
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub35 | Exp 4 | Ep 086 | Train 0.0798/100.00% | Val 0.1101/99.31%
# 早停触发 (基于 Val Loss)。
# 加载 Sub35 (Exp 4) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub35\best_acc_model_exp4.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[28  0  0  0  0]
#  [ 0 11  0  0  0]
#  [ 0  0 11  0  0]
#  [ 0  0  0 42  0]
#  [ 0  0  0  0 52]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0. 100.   0.   0.   0.]
#  [  0.   0. 100.   0.   0.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub35
# --- 受试者 Sub35 实验 4 完成。最终测试 Acc: 100.00% ---
#
# ============================================================2025-11-11 19:59:02
# --- 正在处理受试者: Sub35 | 实验: 5/5 ---...
#
#   已加载 Sub35: 719 个样本。
# 已实例化 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为分类器设置优化器 (LD-Net 已冻结)...
# Using Adam optimizer, initial learning rate:  0.0005
#   > 使用 AdamW 优化器, lr=0.0005
# Validation loss decreased (inf --> 1.025430).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 63.19% (已保存)
# Validation loss decreased (1.025430 --> 1.010915).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 83.33% (已保存)
# Validation loss decreased (1.010915 --> 0.969900).  Saving model ...
# Validation loss decreased (0.969900 --> 0.856940).  Saving model ...
# Validation loss decreased (0.856940 --> 0.691956).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 84.72% (已保存)
# Validation loss decreased (0.691956 --> 0.494707).  Saving model ...
# Validation loss decreased (0.494707 --> 0.459613).  Saving model ...
# Validation loss decreased (0.459613 --> 0.386066).  Saving model ...
# Validation loss decreased (0.386066 --> 0.367612).  Saving model ...
# Validation loss decreased (0.367612 --> 0.310139).  Saving model ...
# Sub35 | Exp 5 | Ep 010 | Train 0.4070/83.83% | Val 0.3101/84.72%
# Validation loss decreased (0.310139 --> 0.286052).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.286052 --> 0.267904).  Saving model ...
# Validation loss decreased (0.267904 --> 0.244587).  Saving model ...
# Validation loss decreased (0.244587 --> 0.218971).  Saving model ...
# Validation loss decreased (0.218971 --> 0.218054).  Saving model ...
# Validation loss decreased (0.218054 --> 0.216387).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 85.42% (已保存)
# Validation loss decreased (0.216387 --> 0.198074).  Saving model ...
# Validation loss decreased (0.198074 --> 0.188686).  Saving model ...
# Sub35 | Exp 5 | Ep 020 | Train 0.1906/89.74% | Val 0.1887/83.33%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.188686 --> 0.187537).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# Sub35 | Exp 5 | Ep 030 | Train 0.1346/91.83% | Val 0.2022/75.69%
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# Sub35 | Exp 5 | Ep 040 | Train 0.1464/90.26% | Val 0.2148/75.00%
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# Sub35 | Exp 5 | Ep 050 | Train 0.1294/91.65% | Val 0.2120/75.00%
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub35 | Exp 5 | Ep 052 | Train 0.1303/91.30% | Val 0.2129/75.00%
# 早停触发 (基于 Val Loss)。
# 加载 Sub35 (Exp 5) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub35\best_acc_model_exp5.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[28  0  0  0  0]
#  [ 0  0  0  0 11]
#  [ 0  0  1 10  0]
#  [ 0  0  0 42  0]
#  [ 0  0  0  0 52]]
# Normalized Confusion Matrix:
# [[100.           0.           0.           0.           0.        ]
#  [  0.           0.           0.           0.         100.        ]
#  [  0.           0.           9.09090909  90.90909091   0.        ]
#  [  0.           0.           0.         100.           0.        ]
#  [  0.           0.           0.           0.         100.        ]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\Sub35
# --- 受试者 Sub35 实验 5 完成。最终测试 Acc: 85.42% ---
#
# ============================================================2025-11-11 19:59:07
# --- 所有受试者处理完毕 ---...
#
# ✅ 包含50次运行的详细CSV已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\summary_by_subject.csv
# ✅ 【最终报告 (mean+std)】(12行) 已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_FocalLoss_1C\all_metrics_averaged_results.csv
#
# --- 检查 Sub02 ---
# Sub02 新的5次实验平均准确率: 71.753%
