# %%
#单元格1
import os
import sys
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from trainTest.metrics.get_test_metrics import PlotConfusionMatrix
import torch.nn.functional as F
import warnings

warnings.filterwarnings("ignore")

# --- 关键：确保项目根目录在路径中 ---
path = os.path.join(os.getcwd(), '..', '..')
sys.path.append(path)

# --- 导入您的项目文件 ---
from utils.common_utils import printlog, set_seed, make_dir, calculate_and_save_metrics
from utils.common_params import *  #
from models.LD_Net import LD_Net

# --- 💡 关键修正：导入 CNNRNNs 类 ---
from models.CNNRNNs import CNNRNNs

from trainTest.early_stopping.early_stopping import EarlyStopping
from trainTest.optimizers.get_optimizer import Optimizer
from trainTest.losses.get_loss import get_classification_loss
from trainTest.lr_schedulers.get_lr_scheduler import LrScheduler
# 设置随机种子
set_seed(seed=42)
print("所有依赖导入成功。")
# Out:
# 所有依赖导入成功。

# %%
# 单元格 2
# === 1. 数据集选择 ===
DATASET_NAME = "SIAT"
# --- 💡 关键修改 (方案7) ---
DENOISE_METHOD = 'LD_Net_Online_Classification'
MODEL_TYPE = 'SC-BiGRU_Diff_FocalLoss'  # <-- 新的保存文件夹
# --- 修改结束 ---
n_channels_check = 9

# === 2. 关键路径设置 ===
LD_NET_MODEL_PATH = os.path.join(
    os.getcwd(), 'checkpoints', 'LD_Net_SIAT', 'ld_net_best_model.pth'
)
base_data_path = os.path.join(path, "preProcessing")
DATA_DIR = os.path.join(
    base_data_path, "SIAT_LLMD_trainData", "Denoising_TrainSet_XY"
)

# --- 3. 模型与训练设置 ---
BATCH_SIZE = 64
LEARNING_RATE = 5e-4 # (0.0005)
EPOCHS = 200
PATIENCE = 30
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === 4. 检查参数 ===
print(f"--- 方案七: 固定 LD-Net + {MODEL_TYPE} ---") # <-- 修改
print(f"设备: {DEVICE}")
print(f"将加载 LD-Net 降噪器: {os.path.abspath(LD_NET_MODEL_PATH)}")
print(f"将加载 *成对数据* (X, Y) 源: {os.path.abspath(DATA_DIR)}")
if C != n_channels_check:
    print(f"⚠️ 警告: common_params.py 中的 C={C} 与 SIAT (C=9) 不匹配!")
else:
    print("✅ C 参数检查通过。")

# === 5. 结果保存路径 ===
save_dir_root = os.path.join(path, 'results', DENOISE_METHOD, MODEL_TYPE)
save_dir_models_temp = save_dir_root
make_dir(save_dir_root)

print(f"✅ 最终结果 (CSV/PNG) 将保存到: {os.path.abspath(save_dir_root)}")
print(f"✅ 临时模型 (PTH) 将保存到: {os.path.abspath(save_dir_models_temp)}")
# Out:
# --- 方案七: 固定 LD-Net + SC-BiGRU_Diff_FocalLoss ---
# 设备: cuda
# 将加载 LD-Net 降噪器: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\checkpoints\LD_Net_SIAT\ld_net_best_model.pth
# 将加载 *成对数据* (X, Y) 源: E:\基于肌电图的下肢运动模式识别\Code2\preProcessing\SIAT_LLMD_trainData\Denoising_TrainSet_XY
# ✅ C 参数检查通过。
# ✅ 最终结果 (CSV/PNG) 将保存到: E:\基于肌电图的下肢运动模式识别\Code2\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss
# ✅ 临时模型 (PTH) 将保存到: E:\基于肌电图的下肢运动模式识别\Code2\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss

# %%
#单元格3
print("--- 正在加载 LD-Net 降噪模型 (步骤三的结果) ---")
try:
    model_denoise = torch.load(LD_NET_MODEL_PATH, weights_only=False)
    model_denoise.to(DEVICE)
    model_denoise.eval()
    print("✅ LD-Net 降噪模型加载成功并设为 eval() 模式。")
except Exception as e:
    print(f"❌ 加载 LD-Net 模型失败: {e}")
    print("请确保 步骤三 已成功运行，且 LD_NET_MODEL_PATH 路径正确。")
    raise e
# Out:
# --- 正在加载 LD-Net 降噪模型 (步骤三的结果) ---
# ✅ LD-Net 降噪模型加载成功并设为 eval() 模式。

# %%
#单元格4
import glob


class LdNetClassificationDataset(Dataset):
    """
    用于分类器训练的数据集。
    从 步骤一 的 'Denoising_TrainSet_XY' 文件夹加载数据。
    """

    def __init__(self, data_dir, subject_id):
        self.data_dir = data_dir
        self.subject_id = subject_id

        # --- 匹配 'Denoising_TrainSet_XY' 的文件名 ---
        file_name_prefix = '_XY_TrainData.npz'
        search_path = os.path.join(self.data_dir, f"{self.subject_id}{file_name_prefix}")
        file_paths = glob.glob(search_path)

        if not file_paths:
            print(f"警告: 在 {self.data_dir} 中未找到 {self.subject_id}{file_name_prefix}。")
            self.samples = np.empty((0, C, window))
            self.labels_encoded = np.empty((0,))
            return

        try:
            data = np.load(file_paths[0])
            # 步骤一 保存的键是 'noisy_X' 和 'sub_motion_label_encoded'
            self.samples = data['noisy_X'].astype(np.float32)
            self.labels_encoded = data['sub_motion_label_encoded'].astype(np.int64)
            print(f"  已加载 {self.subject_id}: {self.samples.shape[0]} 个样本。")

        except Exception as e:
            print(f"加载 {file_paths[0]} 出错: {e}")
            self.samples = np.empty((0, C, window))
            self.labels_encoded = np.empty((0,))

    def __len__(self):
        return self.samples.shape[0]

    def __getitem__(self, idx):
        # 返回 噪声X 和 标签Y
        return self.samples[idx], self.labels_encoded[idx]


print("✅ 分类器数据集 (LdNetClassificationDataset) 定义完毕。")
# Out:
# ✅ 分类器数据集 (LdNetClassificationDataset) 定义完毕。

# %%
# 单元格 5 (方案 7: 固定 LD-Net + BiGRU + 特征工程 + Focal Loss)
from sklearn.model_selection import train_test_split
from trainTest.metrics.get_test_metrics import PlotConfusionMatrix
import torch.optim as optim
import numpy as np
import torch.nn as nn
from trainTest.metrics.metrics_utils import (
    get_accuracy, get_precision, get_recall, get_f1, get_specificity
)
from sklearn.metrics import roc_auc_score
import torch.nn.functional as F

# --- 💡 关键修改 (方案 7): 定义 Focal Loss ---
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha # (alpha 是可选的类权重)
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        # (inputs 是 [B, C], targets 是 [B])
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)

        focal_loss = (1 - pt)**self.gamma * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss
# --- 修正结束 ---

# --- (本地指标函数 _calc_cls_metrics 保持不变) ---
def _calc_cls_metrics(y_true, y_pred, y_scores=None):
    # ... (与你上一个脚本中的 _calc_cls_metrics 保持完全一致)
    y_true = np.asarray(y_true); y_pred = np.asarray(y_pred)
    metrics = {
        'Accuracy': get_accuracy(y_true, y_pred), 'Precision': get_precision(y_true, y_pred),
        'Recall': get_recall(y_true, y_pred), 'F1': get_f1(y_true, y_pred),
        'Specificity': get_specificity(y_true, y_pred) ,
    }
    auc_pct = 0.0
    if y_scores is not None:
        if isinstance(y_scores, list):
            try: y_scores = np.asarray(y_scores)
            except Exception: y_scores = None
        if isinstance(y_scores, np.ndarray) and y_scores.ndim == 2 and y_scores.shape[1] > 1:
            try:
                auc = roc_auc_score(y_true, y_scores, multi_class='ovr', average='macro')
                auc_pct = round(auc * 100.0, 3)
            except Exception: auc_pct = 0.0
    metrics['AUC'] = auc_pct
    return metrics
# --- 指标函数结束 ---

# --- (创建 2 通道输入 _create_2ch_input 保持不变) ---
def _create_2ch_input(out, C_channels=9):
    if isinstance(out, (list, tuple)): t = out[0]
    else: t = out
    if not (t.dim() == 3 and t.size(1) == C_channels):
         raise RuntimeError(f"LD-Net (eval) 输出形状 {tuple(t.shape)} 异常")
    ch1_signal = t.unsqueeze(1)
    ch2_diff = t[..., 1:] - t[..., :-1]
    ch2_diff_padded = F.pad(ch2_diff, (1, 0), 'constant', 0)
    ch2_diff_signal = ch2_diff_padded.unsqueeze(1)
    return torch.cat([ch1_signal, ch2_diff_signal], dim=1) # -> [B, 2, 9, L]

# --- (TwoChanStem 保持不变) ---
class TwoChanStem(nn.Module):
    def __init__(self, in_channels=2, out_channels=1):
        super().__init__()
        self.fuse = nn.Conv2d(in_channels, out_channels, kernel_size=(1,1), stride=(1,1), padding=0, bias=True)
        self.bn   = nn.BatchNorm2d(out_channels)
        self.act  = nn.ReLU()
    def forward(self, x):
        x = self.fuse(x); x = self.bn(x); return self.act(x)

# --- (train_one_epoch 和 test_one_epoch 保持不变) ---
def train_one_epoch(model_classifier, twochan_stem,
                    model_denoiser, train_loader, criterion, optimizer, device):
    model_classifier.train(); twochan_stem.train()
    train_loss = 0.; total_num = 0; y_true_all = []; y_pred_all = []
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        with torch.no_grad():
            out = model_denoiser(inputs)
            x_2ch = _create_2ch_input(out, C_channels=C)
        inputs_denoised = twochan_stem(x_2ch)
        outputs = model_classifier(inputs_denoised)
        loss    = criterion(outputs, labels) # (现在这里是 Focal Loss)
        optimizer.zero_grad(); loss.backward(); optimizer.step()
        bs = labels.size(0)
        train_loss += loss.item() * bs; total_num  += bs
        y_true_all.extend(labels.detach().cpu().numpy())
        y_pred_all.extend(torch.max(outputs, 1)[1].detach().cpu().numpy())
    return train_loss/total_num, _calc_cls_metrics(y_true_all, y_pred_all, None)

@torch.no_grad()
def test_one_epoch(model_classifier, twochan_stem,
                   model_denoiser, test_loader, criterion, device):
    model_classifier.eval(); twochan_stem.eval(); model_denoiser.eval()
    test_loss, total_num = 0.0, 0
    y_true_all, y_pred_all, y_scores_all = [], [], []
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        out = model_denoiser(inputs)
        x_2ch = _create_2ch_input(out, C_channels=C)
        inputs_denoised = twochan_stem(x_2ch)
        outputs = model_classifier(inputs_denoised)
        loss    = criterion(outputs, labels) # (现在这里是 Focal Loss)
        bs = labels.size(0)
        test_loss  += loss.item() * bs; total_num  += bs
        y_true_all.extend(labels.detach().cpu().numpy())
        y_pred_all.extend(torch.max(outputs, 1)[1].detach().cpu().numpy())
        y_scores_all.extend(F.softmax(outputs, dim=1).detach().cpu().numpy())
    return test_loss/total_num, _calc_cls_metrics(y_true_all, y_pred_all, np.asarray(y_scores_all)), y_true_all, y_pred_all

def train_test_subject(subject_id, data_dir, model_denoise, device, save_dir_models_temp,
                       model_type, epochs, batch_size, lr, patience, exp_tim):

    dataset = LdNetClassificationDataset(data_dir=data_dir, subject_id=subject_id)
    if len(dataset) == 0: return None
    train_idx, test_idx = train_test_split(
        list(range(len(dataset))), test_size=0.2, random_state=exp_tim, stratify=dataset.labels_encoded
    )

    # --- 💡 关键修改 (方案 7): 删除静态类权重 ---
    # (不再需要 class_weights 的计算)
    # --- 修正结束 ---

    train_loader = DataLoader(torch.utils.data.Subset(dataset, train_idx), batch_size=batch_size, shuffle=True,  num_workers=0)
    test_loader  = DataLoader(torch.utils.data.Subset(dataset, test_idx),  batch_size=batch_size, shuffle=False, num_workers=0)

    twochan_stem = TwoChanStem().to(device)
    model_classifier = CNNRNNs(rnn_type='BiGRU').to(device)
    print("已实例化 1x1 Stem 适配器 和 SC-BiGRU 分类器。")

    # --- 💡 关键修改 (方案 7): 使用 Focal Loss ---
    criterion = FocalLoss(gamma=2).to(device) # (gamma=2 是一个标准起始值)
    print("  > 使用 FocalLoss (gamma=2) 作为损失函数。")
    # --- 修正结束 ---

    # --- 💡 关键修改 (方案 7): 修复优化器 ---
    print("正在为 Stem 和 分类器 设置优化器 (LD-Net 已冻结)...")
    # (GPT 建议: 两个模块都从头学，使用相同的学习率)
    all_params_to_train = list(twochan_stem.parameters()) + list(model_classifier.parameters())
    # (我们绕过 Optimizer 类，直接使用 AdamW)
    optimizer = optim.AdamW(all_params_to_train, lr=lr, weight_decay=1e-4)
    print(f"  > 使用 torch.optim.AdamW (lr={lr}) 训练 Stem 和 分类器。")
    # --- 修正结束 ---

    # 4. Scheduler & EarlyStopping (不变)
    scheduler_params = {
        'ReduceLROnPlateau': {
            'mode':'min','factor':0.1,'patience':5,'threshold':1e-4,'min_lr':1e-8
        }
    }
    scheduler = LrScheduler(optimizer=optimizer, scheduler_type='ReduceLROnPlateau',
                            params=scheduler_params,
                            max_epoch=epochs).get_scheduler()
    save_dir_subj = os.path.join(save_dir_models_temp, subject_id)
    make_dir(save_dir_subj)
    best_loss_path = os.path.join(save_dir_subj, f'best_loss_model_exp{exp_tim}.pth')
    early_stopping  = EarlyStopping(patience=patience, verbose=True, path=best_loss_path)
    best_acc = -1.0
    best_acc_path = os.path.join(save_dir_subj, f'best_acc_model_exp{exp_tim}.pth')

    def save_models_checkpoint(path):
        torch.save({
            'twochan_stem_state_dict': twochan_stem.state_dict(),
            'model_classifier_state_dict': model_classifier.state_dict(),
        }, path)

    # 5. 训练循环
    for epoch in range(1, epochs+1):
        train_loss, train_metrics = train_one_epoch(
            model_classifier, twochan_stem, model_denoise,
            train_loader, criterion, optimizer, device
        )
        val_loss, val_metrics, _, _ = test_one_epoch(
            model_classifier, twochan_stem, model_denoise,
            test_loader, criterion, device
        )
        scheduler.step(val_loss)
        model_state_dict_to_save = {
            'twochan_stem_state_dict': twochan_stem.state_dict(),
            'model_classifier_state_dict': model_classifier.state_dict(),
        }
        early_stopping(val_loss, model_state_dict_to_save)
        val_acc = val_metrics['Accuracy']
        if val_acc > best_acc:
            best_acc = val_acc
            save_models_checkpoint(best_acc_path)
            print(f"    {subject_id} | Exp {exp_tim} | 新的最佳准确率: {val_acc:.2f}% (已保存)")
        if (epoch % 10 == 0) or early_stopping.early_stop:
            print(f"{subject_id} | Exp {exp_tim} | Ep {epoch:03d} | "
                  f"Train {train_loss:.4f}/{train_metrics['Accuracy']:.2f}% | "
                  f"Val {val_loss:.4f}/{val_metrics['Accuracy']:.2f}%")
        if early_stopping.early_stop:
            print("早停触发 (基于 Val Loss)。"); break

    # 6. 加载最佳
    load_path = best_acc_path if os.path.exists(best_acc_path) else best_loss_path
    print(f"加载 {subject_id} (Exp {exp_tim}) 的最佳模型 (来自: {load_path})...")
    best_stem = TwoChanStem().to(device)
    best_classifier = CNNRNNs(rnn_type='BiGRU').to(device)
    ckpt = torch.load(load_path)
    best_stem.load_state_dict(ckpt['twochan_stem_state_dict'])
    best_classifier.load_state_dict(ckpt['model_classifier_state_dict'])

    # 7. 最终评估
    test_loss_final, test_metrics_final, y_true_final, y_pred_final = test_one_epoch(
        best_classifier, best_stem, model_denoise,
        test_loader, criterion, device
    )

    # 8. 混淆矩阵 (不变)
    print('正在计算并保存混淆矩阵...')
    motions_list_cm = ['WAK', 'STDUP', 'SITDN', 'UPS', 'DNS']
    cm_save_jpg_name = os.path.join(save_dir_subj, f'confusion_matrix_exp{exp_tim}.jpg')
    cm_save_csv_name = os.path.join(save_dir_subj, f'confusion_matrix_exp{exp_tim}.xlsx')
    plot_confusion_matrix = PlotConfusionMatrix(
        y_true_final, y_pred_final, label_type=motions_list_cm,
        show_type='all', plot=False, save_fig=True, save_results=True, cmap='YlGnBu'
    )
    plot_confusion_matrix.get_confusion_matrix(cm_save_jpg_name, cm_save_csv_name)
    print(f'混淆矩阵已保存到: {save_dir_subj}')

    test_metrics_final['Subject'] = subject_id
    return test_metrics_final

print("✅ 训练/测试函数 (train_test_subject) [方案7: 特征工程 + Focal Loss] 定义完毕。")
# Out:
# ✅ 训练/测试函数 (train_test_subject) [方案7: 特征工程 + Focal Loss] 定义完毕。

# %%
#单元格6
import pandas as pd
import numpy as np

# (来自 common_params.py)
subjects_list = ['Sub01', 'Sub02', 'Sub03', 'Sub04', 'Sub05', 'Sub31', 'Sub32', 'Sub33', 'Sub34', 'Sub35']

# 1. --- 初始化列表 ---
metrics_all_subjects = []

# (确保 单元格 2 已运行)
printlog(f"--- 开始在 {DATASET_NAME} 上执行 {DENOISE_METHOD} + {MODEL_TYPE} 受试者内测试 ---", time=True,
         line_break=True)

# 2. --- 主训练循环 (与你之前的一样) ---
for subject in subjects_list:
    for exp_tim in range(1, K_of_repeated_experiments + 1):

        printlog(f"--- 正在处理受试者: {subject} | 实验: {exp_tim}/{K_of_repeated_experiments} ---", time=True, line_break=True)

        test_metrics = train_test_subject(
            subject_id=subject,
            data_dir=DATA_DIR,
            model_denoise=model_denoise,
            device=DEVICE,
            save_dir_models_temp=save_dir_models_temp,
            model_type=MODEL_TYPE,
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            lr=LEARNING_RATE,
            patience=PATIENCE,
            exp_tim=exp_tim
        )

        if test_metrics:
            test_metrics['Experiment'] = exp_tim
            metrics_all_subjects.append(test_metrics)
            print(f"--- 受试者 {subject} 实验 {exp_tim} 完成。最终测试 Acc: {test_metrics['Accuracy']:.2f}% ---")
# --- 主循环结束 ---


printlog(f"--- 所有受试者处理完毕 ---", time=True, line_break=True)

# 3. --- 💡 关键修改：计算并保存为【图片样式】 ---
if metrics_all_subjects:
    # 3.1. 保存【所有50次运行】的详细原始数据
    df_summary = pd.DataFrame(metrics_all_subjects)
    save_path_summary_by_subject = os.path.join(save_dir_root, 'summary_by_subject.csv')
    df_summary.to_csv(save_path_summary_by_subject, index=False, float_format='%.3f')
    print(f"✅ 包含50次运行的详细CSV已保存到: {save_path_summary_by_subject}")

    # 3.2. 计算【每个受试者的平均值】(数字)
    df_avg_by_subject = df_summary.groupby('Subject').mean(numeric_only=True)
    # 计算【每个受试者的标准差】(数字)
    df_std_by_subject = df_summary.groupby('Subject').std(numeric_only=True)

    # 3.3. 创建【受试者10行】的格式化 (mean+std) DataFrame
    df_formatted_subjects = pd.DataFrame(index=df_avg_by_subject.index)

    # 确定要格式化的列 (排除 'Experiment')
    metrics_cols = [col for col in df_avg_by_subject.columns if col != 'Experiment']

    for col in metrics_cols:
        # 格式化为 "均值 + 标准差"，并保留4位小数 (根据图片)
        df_formatted_subjects[col] = df_avg_by_subject[col].map('{:.4f}'.format) + \
                                     "+" + \
                                     df_std_by_subject[col].map('{:.4f}'.format)

    # 3.4. 计算【所有受试者平均值的平均值】(数字)
    df_total_avg = df_avg_by_subject[metrics_cols].mean().to_frame().T

    # 3.5. 计算【所有受试者平均值的标准差】(数字)
    df_total_std = df_avg_by_subject[metrics_cols].std().to_frame().T

    # 3.6. 将总平均值和总标准差格式化为DataFrame (用于拼接)
    # 只保留小数 (根据图片)
    df_total_avg_formatted = df_total_avg.applymap(lambda x: f"{x:.4f}")
    df_total_std_formatted = df_total_std.applymap(lambda x: f"{x:.4f}")

    # 更改索引名以便拼接
    df_total_avg_formatted.index = ['mean']
    df_total_std_formatted.index = ['std']

    # 3.7. 拼接所有部分：10行 (mean+std) + 1行 (total mean) + 1行 (total std)
    df_final_report = pd.concat([df_formatted_subjects, df_total_avg_formatted, df_total_std_formatted])

    # 3.8. 保存最终的报告
    save_path_final_report = os.path.join(save_dir_root, 'all_metrics_averaged_results.csv')
    # index=True 是因为 Subject/mean/std 现在是索引
    df_final_report.to_csv(save_path_final_report, index=True)
    print(f"✅ 【最终报告 (mean+std)】(12行) 已保存到: {save_path_final_report}")

    # (现在 "alone_subject_averaged_results.csv" 已经合并到上面了，不再单独保存)

    # 3.9. 检查 Sub02 (使用未格式化的 df_avg_by_subject)
    try:
        sub02_new_avg = df_avg_by_subject.loc['Sub02']['Accuracy']
        print(f"\n--- 检查 Sub02 ---")
        print(f"Sub02 新的5次实验平均准确率: {sub02_new_avg:.3f}%")
    except Exception as e:
        print(f"无法自动检查 Sub02 的新平均值: {e}")

else:
    print("没有受试者被成功处理。")
# Out:
# ============================================================2025-11-11 17:24:24
# --- 开始在 SIAT 上执行 LD_Net_Online_Classification + SC-BiGRU_Diff_FocalLoss 受试者内测试 ---...
#
#
# ============================================================2025-11-11 17:24:24
# --- 正在处理受试者: Sub01 | 实验: 1/5 ---...
#
#   已加载 Sub01: 690 个样本。
# 已实例化 1x1 Stem 适配器 和 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为 Stem 和 分类器 设置优化器 (LD-Net 已冻结)...
#   > 使用 torch.optim.AdamW (lr=0.0005) 训练 Stem 和 分类器。
# Validation loss decreased (inf --> 1.028170).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 27.54% (已保存)
# Validation loss decreased (1.028170 --> 1.021523).  Saving model ...
# Validation loss decreased (1.021523 --> 0.997299).  Saving model ...
# Validation loss decreased (0.997299 --> 0.926772).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 52.90% (已保存)
# Validation loss decreased (0.926772 --> 0.801878).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 86.96% (已保存)
# Validation loss decreased (0.801878 --> 0.559275).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 97.83% (已保存)
# Validation loss decreased (0.559275 --> 0.463810).  Saving model ...
# Validation loss decreased (0.463810 --> 0.346878).  Saving model ...
# Validation loss decreased (0.346878 --> 0.317914).  Saving model ...
# Validation loss decreased (0.317914 --> 0.271983).  Saving model ...
# Sub01 | Exp 1 | Ep 010 | Train 0.4109/92.39% | Val 0.2720/97.10%
# Validation loss decreased (0.271983 --> 0.248197).  Saving model ...
# Validation loss decreased (0.248197 --> 0.247406).  Saving model ...
# Validation loss decreased (0.247406 --> 0.197762).  Saving model ...
# Validation loss decreased (0.197762 --> 0.185878).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.185878 --> 0.184359).  Saving model ...
# Validation loss decreased (0.184359 --> 0.137390).  Saving model ...
# EarlyStopping counter: 1 out of 30
#     Sub01 | Exp 1 | 新的最佳准确率: 98.55% (已保存)
# Validation loss decreased (0.137390 --> 0.119363).  Saving model ...
# Validation loss decreased (0.119363 --> 0.108765).  Saving model ...
# Sub01 | Exp 1 | Ep 020 | Train 0.1471/99.82% | Val 0.1088/98.55%
# Validation loss decreased (0.108765 --> 0.097877).  Saving model ...
# Validation loss decreased (0.097877 --> 0.096054).  Saving model ...
# Validation loss decreased (0.096054 --> 0.088835).  Saving model ...
# Validation loss decreased (0.088835 --> 0.078507).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.078507 --> 0.076510).  Saving model ...
# Validation loss decreased (0.076510 --> 0.073656).  Saving model ...
# Validation loss decreased (0.073656 --> 0.059503).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.059503 --> 0.055272).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 99.28% (已保存)
# Sub01 | Exp 1 | Ep 030 | Train 0.0912/98.19% | Val 0.0553/99.28%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.055272 --> 0.048946).  Saving model ...
# Validation loss decreased (0.048946 --> 0.043114).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.043114 --> 0.042490).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.042490 --> 0.031192).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.031192 --> 0.026273).  Saving model ...
# Sub01 | Exp 1 | Ep 040 | Train 0.0590/99.46% | Val 0.0263/99.28%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.026273 --> 0.022407).  Saving model ...
#     Sub01 | Exp 1 | 新的最佳准确率: 100.00% (已保存)
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.022407 --> 0.016947).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Sub01 | Exp 1 | Ep 050 | Train 0.0413/99.46% | Val 0.0180/98.55%
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# Sub01 | Exp 1 | Ep 060 | Train 0.0329/99.46% | Val 0.0175/98.55%
# EarlyStopping counter: 14 out of 30
# Validation loss decreased (0.016947 --> 0.016770).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# Sub01 | Exp 1 | Ep 070 | Train 0.0288/99.82% | Val 0.0177/98.55%
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# Validation loss decreased (0.016770 --> 0.016748).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Sub01 | Exp 1 | Ep 080 | Train 0.0629/97.10% | Val 0.0176/98.55%
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# Validation loss decreased (0.016748 --> 0.016357).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# Sub01 | Exp 1 | Ep 090 | Train 0.0334/99.82% | Val 0.0166/98.55%
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# Sub01 | Exp 1 | Ep 100 | Train 0.0262/100.00% | Val 0.0175/98.55%
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# Validation loss decreased (0.016357 --> 0.015997).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Sub01 | Exp 1 | Ep 110 | Train 0.0262/99.82% | Val 0.0183/98.55%
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# Sub01 | Exp 1 | Ep 120 | Train 0.0358/99.46% | Val 0.0173/98.55%
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# Sub01 | Exp 1 | Ep 130 | Train 0.0393/99.46% | Val 0.0184/98.55%
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub01 | Exp 1 | Ep 137 | Train 0.0328/99.28% | Val 0.0175/98.55%
# 早停触发 (基于 Val Loss)。
# 加载 Sub01 (Exp 1) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub01\best_acc_model_exp1.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 20  0  0]
#  [ 0  0  0 38  0]
#  [ 0  0  0  0 33]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0. 100.   0.   0.   0.]
#  [  0.   0. 100.   0.   0.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub01
# --- 受试者 Sub01 实验 1 完成。最终测试 Acc: 100.00% ---
#
# ============================================================2025-11-11 17:24:43
# --- 正在处理受试者: Sub01 | 实验: 2/5 ---...
#
#   已加载 Sub01: 690 个样本。
# 已实例化 1x1 Stem 适配器 和 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为 Stem 和 分类器 设置优化器 (LD-Net 已冻结)...
#   > 使用 torch.optim.AdamW (lr=0.0005) 训练 Stem 和 分类器。
# Validation loss decreased (inf --> 1.028888).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 23.91% (已保存)
# Validation loss decreased (1.028888 --> 1.012410).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 51.45% (已保存)
# Validation loss decreased (1.012410 --> 0.959446).  Saving model ...
# Validation loss decreased (0.959446 --> 0.843516).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 55.80% (已保存)
# Validation loss decreased (0.843516 --> 0.688590).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 71.74% (已保存)
# Validation loss decreased (0.688590 --> 0.538087).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 78.26% (已保存)
# Validation loss decreased (0.538087 --> 0.462828).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 84.06% (已保存)
# Validation loss decreased (0.462828 --> 0.387761).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 85.51% (已保存)
# Validation loss decreased (0.387761 --> 0.367871).  Saving model ...
# Validation loss decreased (0.367871 --> 0.335187).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 86.23% (已保存)
# Sub01 | Exp 2 | Ep 010 | Train 0.4332/84.78% | Val 0.3352/86.23%
# Validation loss decreased (0.335187 --> 0.315145).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 86.96% (已保存)
# Validation loss decreased (0.315145 --> 0.268089).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 89.86% (已保存)
# Validation loss decreased (0.268089 --> 0.254672).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 93.48% (已保存)
# Validation loss decreased (0.254672 --> 0.240012).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 98.55% (已保存)
# Validation loss decreased (0.240012 --> 0.197059).  Saving model ...
#     Sub01 | Exp 2 | 新的最佳准确率: 100.00% (已保存)
# Validation loss decreased (0.197059 --> 0.184542).  Saving model ...
# Validation loss decreased (0.184542 --> 0.181069).  Saving model ...
# Validation loss decreased (0.181069 --> 0.158064).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.158064 --> 0.153939).  Saving model ...
# Sub01 | Exp 2 | Ep 020 | Train 0.2418/95.47% | Val 0.1539/97.10%
# Validation loss decreased (0.153939 --> 0.133063).  Saving model ...
# Validation loss decreased (0.133063 --> 0.110490).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.110490 --> 0.097251).  Saving model ...
# Validation loss decreased (0.097251 --> 0.087333).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.087333 --> 0.082837).  Saving model ...
# Validation loss decreased (0.082837 --> 0.071935).  Saving model ...
# Validation loss decreased (0.071935 --> 0.070685).  Saving model ...
# Validation loss decreased (0.070685 --> 0.066073).  Saving model ...
# Sub01 | Exp 2 | Ep 030 | Train 0.1097/99.28% | Val 0.0661/100.00%
# Validation loss decreased (0.066073 --> 0.057613).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.057613 --> 0.052909).  Saving model ...
# Validation loss decreased (0.052909 --> 0.048252).  Saving model ...
# Validation loss decreased (0.048252 --> 0.045057).  Saving model ...
# Validation loss decreased (0.045057 --> 0.043612).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.043612 --> 0.042999).  Saving model ...
# Validation loss decreased (0.042999 --> 0.038478).  Saving model ...
# Validation loss decreased (0.038478 --> 0.033354).  Saving model ...
# Sub01 | Exp 2 | Ep 040 | Train 0.0878/97.46% | Val 0.0334/100.00%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.033354 --> 0.029958).  Saving model ...
# Validation loss decreased (0.029958 --> 0.027116).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.027116 --> 0.024410).  Saving model ...
# Validation loss decreased (0.024410 --> 0.023820).  Saving model ...
# Validation loss decreased (0.023820 --> 0.022177).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Sub01 | Exp 2 | Ep 050 | Train 0.0649/98.01% | Val 0.0459/97.10%
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.022177 --> 0.021183).  Saving model ...
# Validation loss decreased (0.021183 --> 0.019554).  Saving model ...
# Validation loss decreased (0.019554 --> 0.017627).  Saving model ...
# Validation loss decreased (0.017627 --> 0.016302).  Saving model ...
# Validation loss decreased (0.016302 --> 0.015934).  Saving model ...
# Validation loss decreased (0.015934 --> 0.014559).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Sub01 | Exp 2 | Ep 060 | Train 0.0736/96.92% | Val 0.0196/99.28%
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Validation loss decreased (0.014559 --> 0.008400).  Saving model ...
# Validation loss decreased (0.008400 --> 0.007517).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# Sub01 | Exp 2 | Ep 070 | Train 0.0902/96.38% | Val 0.0080/100.00%
# Validation loss decreased (0.007517 --> 0.007158).  Saving model ...
# Validation loss decreased (0.007158 --> 0.006663).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.006663 --> 0.006659).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.006659 --> 0.006636).  Saving model ...
# Validation loss decreased (0.006636 --> 0.006168).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.006168 --> 0.006133).  Saving model ...
# Sub01 | Exp 2 | Ep 080 | Train 0.0240/99.82% | Val 0.0061/100.00%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Validation loss decreased (0.006133 --> 0.005982).  Saving model ...
# Validation loss decreased (0.005982 --> 0.005732).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Sub01 | Exp 2 | Ep 090 | Train 0.0353/98.37% | Val 0.0061/100.00%
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# Sub01 | Exp 2 | Ep 100 | Train 0.0229/99.28% | Val 0.0061/100.00%
# Validation loss decreased (0.005732 --> 0.005697).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# Sub01 | Exp 2 | Ep 110 | Train 0.0318/98.73% | Val 0.0064/100.00%
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# Validation loss decreased (0.005697 --> 0.005606).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Sub01 | Exp 2 | Ep 120 | Train 0.0200/99.46% | Val 0.0062/100.00%
# EarlyStopping counter: 6 out of 30
# Validation loss decreased (0.005606 --> 0.005526).  Saving model ...
# Validation loss decreased (0.005526 --> 0.005447).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# Sub01 | Exp 2 | Ep 130 | Train 0.0343/98.55% | Val 0.0057/100.00%
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# Sub01 | Exp 2 | Ep 140 | Train 0.0249/99.28% | Val 0.0063/100.00%
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# Sub01 | Exp 2 | Ep 150 | Train 0.0239/99.09% | Val 0.0062/100.00%
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub01 | Exp 2 | Ep 153 | Train 0.0278/99.28% | Val 0.0060/100.00%
# 早停触发 (基于 Val Loss)。
# 加载 Sub01 (Exp 2) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub01\best_acc_model_exp2.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 20  0  0]
#  [ 0  0  0 38  0]
#  [ 0  0  0  0 33]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0. 100.   0.   0.   0.]
#  [  0.   0. 100.   0.   0.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub01
# --- 受试者 Sub01 实验 2 完成。最终测试 Acc: 100.00% ---
#
# ============================================================2025-11-11 17:25:02
# --- 正在处理受试者: Sub01 | 实验: 3/5 ---...
#
#   已加载 Sub01: 690 个样本。
# 已实例化 1x1 Stem 适配器 和 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为 Stem 和 分类器 设置优化器 (LD-Net 已冻结)...
#   > 使用 torch.optim.AdamW (lr=0.0005) 训练 Stem 和 分类器。
# Validation loss decreased (inf --> 1.026401).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 27.54% (已保存)
# Validation loss decreased (1.026401 --> 1.013392).  Saving model ...
# Validation loss decreased (1.013392 --> 0.979647).  Saving model ...
# Validation loss decreased (0.979647 --> 0.892218).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 42.03% (已保存)
# Validation loss decreased (0.892218 --> 0.735838).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 56.52% (已保存)
# Validation loss decreased (0.735838 --> 0.589213).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 64.49% (已保存)
# Validation loss decreased (0.589213 --> 0.470310).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 68.12% (已保存)
# Validation loss decreased (0.470310 --> 0.406466).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 69.56% (已保存)
# Validation loss decreased (0.406466 --> 0.362532).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 71.74% (已保存)
# EarlyStopping counter: 1 out of 30
#     Sub01 | Exp 3 | 新的最佳准确率: 84.06% (已保存)
# Sub01 | Exp 3 | Ep 010 | Train 0.4410/75.91% | Val 0.3777/84.06%
# Validation loss decreased (0.362532 --> 0.311659).  Saving model ...
# Validation loss decreased (0.311659 --> 0.281603).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 86.96% (已保存)
# Validation loss decreased (0.281603 --> 0.271728).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.271728 --> 0.215401).  Saving model ...
# Validation loss decreased (0.215401 --> 0.210384).  Saving model ...
# EarlyStopping counter: 1 out of 30
#     Sub01 | Exp 3 | 新的最佳准确率: 97.10% (已保存)
# Validation loss decreased (0.210384 --> 0.192517).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 99.28% (已保存)
# Validation loss decreased (0.192517 --> 0.178592).  Saving model ...
# Validation loss decreased (0.178592 --> 0.160124).  Saving model ...
#     Sub01 | Exp 3 | 新的最佳准确率: 100.00% (已保存)
# Sub01 | Exp 3 | Ep 020 | Train 0.2539/91.49% | Val 0.1601/100.00%
# Validation loss decreased (0.160124 --> 0.159952).  Saving model ...
# Validation loss decreased (0.159952 --> 0.145923).  Saving model ...
# Validation loss decreased (0.145923 --> 0.139037).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.139037 --> 0.137300).  Saving model ...
# Validation loss decreased (0.137300 --> 0.125710).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.125710 --> 0.115886).  Saving model ...
# Sub01 | Exp 3 | Ep 030 | Train 0.1230/97.28% | Val 0.1159/98.55%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.115886 --> 0.113686).  Saving model ...
# Validation loss decreased (0.113686 --> 0.095698).  Saving model ...
# Validation loss decreased (0.095698 --> 0.085956).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Sub01 | Exp 3 | Ep 040 | Train 0.0915/95.65% | Val 0.1426/86.23%
# EarlyStopping counter: 5 out of 30
# Validation loss decreased (0.085956 --> 0.055464).  Saving model ...
# Validation loss decreased (0.055464 --> 0.048710).  Saving model ...
# Validation loss decreased (0.048710 --> 0.029774).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.029774 --> 0.015863).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Sub01 | Exp 3 | Ep 050 | Train 0.0443/99.46% | Val 0.0524/95.65%
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# Sub01 | Exp 3 | Ep 060 | Train 0.0488/99.28% | Val 0.0447/98.55%
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# Sub01 | Exp 3 | Ep 070 | Train 0.0619/97.83% | Val 0.0534/97.83%
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub01 | Exp 3 | Ep 077 | Train 0.0407/99.09% | Val 0.0450/98.55%
# 早停触发 (基于 Val Loss)。
# 加载 Sub01 (Exp 3) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub01\best_acc_model_exp3.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 20  0  0]
#  [ 0  0  0 38  0]
#  [ 0  0  0  0 33]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0. 100.   0.   0.   0.]
#  [  0.   0. 100.   0.   0.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub01
# --- 受试者 Sub01 实验 3 完成。最终测试 Acc: 100.00% ---
#
# ============================================================2025-11-11 17:25:12
# --- 正在处理受试者: Sub01 | 实验: 4/5 ---...
#
#   已加载 Sub01: 690 个样本。
# 已实例化 1x1 Stem 适配器 和 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为 Stem 和 分类器 设置优化器 (LD-Net 已冻结)...
#   > 使用 torch.optim.AdamW (lr=0.0005) 训练 Stem 和 分类器。
# Validation loss decreased (inf --> 1.027342).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 27.54% (已保存)
# Validation loss decreased (1.027342 --> 1.017825).  Saving model ...
# Validation loss decreased (1.017825 --> 0.975340).  Saving model ...
# Validation loss decreased (0.975340 --> 0.884225).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 31.88% (已保存)
# Validation loss decreased (0.884225 --> 0.751666).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 55.07% (已保存)
# Validation loss decreased (0.751666 --> 0.580071).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 73.19% (已保存)
# Validation loss decreased (0.580071 --> 0.475451).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 75.36% (已保存)
# Validation loss decreased (0.475451 --> 0.435927).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 84.06% (已保存)
# Validation loss decreased (0.435927 --> 0.390610).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 84.78% (已保存)
# Validation loss decreased (0.390610 --> 0.379610).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 86.23% (已保存)
# Sub01 | Exp 4 | Ep 010 | Train 0.4804/80.62% | Val 0.3796/86.23%
# Validation loss decreased (0.379610 --> 0.326242).  Saving model ...
# Validation loss decreased (0.326242 --> 0.316992).  Saving model ...
# Validation loss decreased (0.316992 --> 0.286621).  Saving model ...
# Validation loss decreased (0.286621 --> 0.269097).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 86.96% (已保存)
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.269097 --> 0.241021).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.241021 --> 0.230393).  Saving model ...
# Validation loss decreased (0.230393 --> 0.209233).  Saving model ...
# Validation loss decreased (0.209233 --> 0.203585).  Saving model ...
# Sub01 | Exp 4 | Ep 020 | Train 0.2702/85.87% | Val 0.2036/86.96%
# Validation loss decreased (0.203585 --> 0.197324).  Saving model ...
# Validation loss decreased (0.197324 --> 0.186805).  Saving model ...
# Validation loss decreased (0.186805 --> 0.183787).  Saving model ...
# Validation loss decreased (0.183787 --> 0.169645).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 99.28% (已保存)
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.169645 --> 0.162679).  Saving model ...
#     Sub01 | Exp 4 | 新的最佳准确率: 100.00% (已保存)
# Validation loss decreased (0.162679 --> 0.157519).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.157519 --> 0.152727).  Saving model ...
# Validation loss decreased (0.152727 --> 0.151997).  Saving model ...
# Sub01 | Exp 4 | Ep 030 | Train 0.2282/94.20% | Val 0.1520/99.28%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.151997 --> 0.150772).  Saving model ...
# Validation loss decreased (0.150772 --> 0.140957).  Saving model ...
# Validation loss decreased (0.140957 --> 0.138659).  Saving model ...
# Validation loss decreased (0.138659 --> 0.136354).  Saving model ...
# Validation loss decreased (0.136354 --> 0.134179).  Saving model ...
# Validation loss decreased (0.134179 --> 0.132764).  Saving model ...
# Validation loss decreased (0.132764 --> 0.130596).  Saving model ...
# Validation loss decreased (0.130596 --> 0.128947).  Saving model ...
# Validation loss decreased (0.128947 --> 0.126377).  Saving model ...
# Sub01 | Exp 4 | Ep 040 | Train 0.1576/99.09% | Val 0.1264/100.00%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.126377 --> 0.124450).  Saving model ...
# Validation loss decreased (0.124450 --> 0.123777).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.123777 --> 0.121165).  Saving model ...
# Validation loss decreased (0.121165 --> 0.117843).  Saving model ...
# Validation loss decreased (0.117843 --> 0.116128).  Saving model ...
# Validation loss decreased (0.116128 --> 0.116127).  Saving model ...
# Validation loss decreased (0.116127 --> 0.115272).  Saving model ...
# Validation loss decreased (0.115272 --> 0.113303).  Saving model ...
# Sub01 | Exp 4 | Ep 050 | Train 0.1320/99.09% | Val 0.1133/100.00%
# Validation loss decreased (0.113303 --> 0.111567).  Saving model ...
# Validation loss decreased (0.111567 --> 0.110565).  Saving model ...
# Validation loss decreased (0.110565 --> 0.110013).  Saving model ...
# Validation loss decreased (0.110013 --> 0.109912).  Saving model ...
# Validation loss decreased (0.109912 --> 0.108579).  Saving model ...
# Validation loss decreased (0.108579 --> 0.107845).  Saving model ...
# Validation loss decreased (0.107845 --> 0.106423).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.106423 --> 0.104189).  Saving model ...
# Sub01 | Exp 4 | Ep 060 | Train 0.1331/98.01% | Val 0.1042/100.00%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.104189 --> 0.102453).  Saving model ...
# Validation loss decreased (0.102453 --> 0.100577).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.100577 --> 0.099060).  Saving model ...
# Validation loss decreased (0.099060 --> 0.098876).  Saving model ...
# Validation loss decreased (0.098876 --> 0.098545).  Saving model ...
# Validation loss decreased (0.098545 --> 0.097199).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.097199 --> 0.094968).  Saving model ...
# Sub01 | Exp 4 | Ep 070 | Train 0.1108/99.28% | Val 0.0950/100.00%
# Validation loss decreased (0.094968 --> 0.094427).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.094427 --> 0.094174).  Saving model ...
# Validation loss decreased (0.094174 --> 0.092346).  Saving model ...
# Validation loss decreased (0.092346 --> 0.091276).  Saving model ...
# Validation loss decreased (0.091276 --> 0.090665).  Saving model ...
# Validation loss decreased (0.090665 --> 0.090308).  Saving model ...
# Validation loss decreased (0.090308 --> 0.089373).  Saving model ...
# Validation loss decreased (0.089373 --> 0.087841).  Saving model ...
# Validation loss decreased (0.087841 --> 0.086104).  Saving model ...
# Sub01 | Exp 4 | Ep 080 | Train 0.1083/98.91% | Val 0.0861/100.00%
# Validation loss decreased (0.086104 --> 0.084270).  Saving model ...
# Validation loss decreased (0.084270 --> 0.082183).  Saving model ...
# Validation loss decreased (0.082183 --> 0.079118).  Saving model ...
# Validation loss decreased (0.079118 --> 0.075730).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.075730 --> 0.065255).  Saving model ...
# Validation loss decreased (0.065255 --> 0.062471).  Saving model ...
# Validation loss decreased (0.062471 --> 0.055740).  Saving model ...
# Validation loss decreased (0.055740 --> 0.050646).  Saving model ...
# Validation loss decreased (0.050646 --> 0.046510).  Saving model ...
# Sub01 | Exp 4 | Ep 090 | Train 0.0743/99.46% | Val 0.0465/100.00%
# Validation loss decreased (0.046510 --> 0.040580).  Saving model ...
# Validation loss decreased (0.040580 --> 0.037000).  Saving model ...
# Validation loss decreased (0.037000 --> 0.035833).  Saving model ...
# Validation loss decreased (0.035833 --> 0.034511).  Saving model ...
# Validation loss decreased (0.034511 --> 0.028972).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.028972 --> 0.024821).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.024821 --> 0.020751).  Saving model ...
# Sub01 | Exp 4 | Ep 100 | Train 0.0445/99.46% | Val 0.0208/100.00%
# Validation loss decreased (0.020751 --> 0.017380).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.017380 --> 0.016780).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.016780 --> 0.016757).  Saving model ...
# Validation loss decreased (0.016757 --> 0.014324).  Saving model ...
# Validation loss decreased (0.014324 --> 0.014139).  Saving model ...
# Validation loss decreased (0.014139 --> 0.013928).  Saving model ...
# Validation loss decreased (0.013928 --> 0.013913).  Saving model ...
# Validation loss decreased (0.013913 --> 0.011823).  Saving model ...
# Sub01 | Exp 4 | Ep 110 | Train 0.0300/99.64% | Val 0.0118/100.00%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.011823 --> 0.009338).  Saving model ...
# Validation loss decreased (0.009338 --> 0.008798).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# Sub01 | Exp 4 | Ep 120 | Train 0.0366/99.28% | Val 0.0093/100.00%
# Validation loss decreased (0.008798 --> 0.008127).  Saving model ...
# Validation loss decreased (0.008127 --> 0.007806).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# Sub01 | Exp 4 | Ep 130 | Train 0.0451/98.37% | Val 0.0079/100.00%
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# Validation loss decreased (0.007806 --> 0.007741).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Sub01 | Exp 4 | Ep 140 | Train 0.0309/99.28% | Val 0.0085/100.00%
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# Validation loss decreased (0.007741 --> 0.007529).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# Sub01 | Exp 4 | Ep 150 | Train 0.0510/97.83% | Val 0.0082/100.00%
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# Sub01 | Exp 4 | Ep 160 | Train 0.0248/99.64% | Val 0.0086/100.00%
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# Sub01 | Exp 4 | Ep 170 | Train 0.0495/97.64% | Val 0.0082/100.00%
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub01 | Exp 4 | Ep 173 | Train 0.0272/99.46% | Val 0.0079/100.00%
# 早停触发 (基于 Val Loss)。
# 加载 Sub01 (Exp 4) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub01\best_acc_model_exp4.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 20  0  0]
#  [ 0  0  0 38  0]
#  [ 0  0  0  0 33]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0. 100.   0.   0.   0.]
#  [  0.   0. 100.   0.   0.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub01
# --- 受试者 Sub01 实验 4 完成。最终测试 Acc: 100.00% ---
#
# ============================================================2025-11-11 17:25:33
# --- 正在处理受试者: Sub01 | 实验: 5/5 ---...
#
#   已加载 Sub01: 690 个样本。
# 已实例化 1x1 Stem 适配器 和 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为 Stem 和 分类器 设置优化器 (LD-Net 已冻结)...
#   > 使用 torch.optim.AdamW (lr=0.0005) 训练 Stem 和 分类器。
# Validation loss decreased (inf --> 1.028815).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 27.54% (已保存)
# Validation loss decreased (1.028815 --> 1.024367).  Saving model ...
# Validation loss decreased (1.024367 --> 1.014114).  Saving model ...
# Validation loss decreased (1.014114 --> 1.009893).  Saving model ...
# Validation loss decreased (1.009893 --> 1.004805).  Saving model ...
# Validation loss decreased (1.004805 --> 0.998560).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 28.26% (已保存)
# Validation loss decreased (0.998560 --> 0.928267).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 32.61% (已保存)
# Validation loss decreased (0.928267 --> 0.856804).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 35.51% (已保存)
# Validation loss decreased (0.856804 --> 0.624117).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 60.15% (已保存)
# Validation loss decreased (0.624117 --> 0.546264).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 68.12% (已保存)
# Sub01 | Exp 5 | Ep 010 | Train 0.4495/91.85% | Val 0.5463/68.12%
# Validation loss decreased (0.546264 --> 0.476717).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 74.64% (已保存)
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.476717 --> 0.216513).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 94.93% (已保存)
# Validation loss decreased (0.216513 --> 0.179093).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 97.10% (已保存)
# Validation loss decreased (0.179093 --> 0.125619).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 99.28% (已保存)
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.125619 --> 0.118585).  Saving model ...
# Validation loss decreased (0.118585 --> 0.099947).  Saving model ...
# Sub01 | Exp 5 | Ep 020 | Train 0.1541/98.37% | Val 0.0999/98.55%
# Validation loss decreased (0.099947 --> 0.085504).  Saving model ...
# Validation loss decreased (0.085504 --> 0.076803).  Saving model ...
# Validation loss decreased (0.076803 --> 0.075495).  Saving model ...
# Validation loss decreased (0.075495 --> 0.064134).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.064134 --> 0.052664).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.052664 --> 0.046315).  Saving model ...
#     Sub01 | Exp 5 | 新的最佳准确率: 100.00% (已保存)
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Sub01 | Exp 5 | Ep 030 | Train 0.0971/97.83% | Val 0.0592/97.83%
# Validation loss decreased (0.046315 --> 0.041287).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.041287 --> 0.024022).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Validation loss decreased (0.024022 --> 0.021507).  Saving model ...
# Sub01 | Exp 5 | Ep 040 | Train 0.0379/99.28% | Val 0.0215/98.55%
# Validation loss decreased (0.021507 --> 0.016604).  Saving model ...
# Validation loss decreased (0.016604 --> 0.013085).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# Validation loss decreased (0.013085 --> 0.012545).  Saving model ...
# Validation loss decreased (0.012545 --> 0.011809).  Saving model ...
# Sub01 | Exp 5 | Ep 050 | Train 0.0554/97.28% | Val 0.0118/99.28%
# Validation loss decreased (0.011809 --> 0.011079).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Validation loss decreased (0.011079 --> 0.010321).  Saving model ...
# Validation loss decreased (0.010321 --> 0.010160).  Saving model ...
# Validation loss decreased (0.010160 --> 0.009928).  Saving model ...
# Validation loss decreased (0.009928 --> 0.009888).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Sub01 | Exp 5 | Ep 060 | Train 0.0280/99.46% | Val 0.0104/100.00%
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# Sub01 | Exp 5 | Ep 070 | Train 0.0374/98.55% | Val 0.0108/99.28%
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# Sub01 | Exp 5 | Ep 080 | Train 0.0395/98.55% | Val 0.0107/99.28%
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub01 | Exp 5 | Ep 089 | Train 0.0380/99.09% | Val 0.0107/99.28%
# 早停触发 (基于 Val Loss)。
# 加载 Sub01 (Exp 5) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub01\best_acc_model_exp5.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[29  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 20  0  0]
#  [ 0  0  0 38  0]
#  [ 0  0  0  0 33]]
# Normalized Confusion Matrix:
# [[100.   0.   0.   0.   0.]
#  [  0. 100.   0.   0.   0.]
#  [  0.   0. 100.   0.   0.]
#  [  0.   0.   0. 100.   0.]
#  [  0.   0.   0.   0. 100.]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub01
# --- 受试者 Sub01 实验 5 完成。最终测试 Acc: 100.00% ---
#
# ============================================================2025-11-11 17:25:44
# --- 正在处理受试者: Sub02 | 实验: 1/5 ---...
#
#   已加载 Sub02: 483 个样本。
# 已实例化 1x1 Stem 适配器 和 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为 Stem 和 分类器 设置优化器 (LD-Net 已冻结)...
#   > 使用 torch.optim.AdamW (lr=0.0005) 训练 Stem 和 分类器。
# Validation loss decreased (inf --> 1.029023).  Saving model ...
#     Sub02 | Exp 1 | 新的最佳准确率: 28.87% (已保存)
# Validation loss decreased (1.029023 --> 1.027818).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (1.027818 --> 1.026302).  Saving model ...
# Validation loss decreased (1.026302 --> 1.015251).  Saving model ...
#     Sub02 | Exp 1 | 新的最佳准确率: 34.02% (已保存)
# Validation loss decreased (1.015251 --> 0.910469).  Saving model ...
# Validation loss decreased (0.910469 --> 0.810904).  Saving model ...
#     Sub02 | Exp 1 | 新的最佳准确率: 36.08% (已保存)
# Validation loss decreased (0.810904 --> 0.618904).  Saving model ...
#     Sub02 | Exp 1 | 新的最佳准确率: 63.92% (已保存)
# Validation loss decreased (0.618904 --> 0.587765).  Saving model ...
#     Sub02 | Exp 1 | 新的最佳准确率: 64.95% (已保存)
# Validation loss decreased (0.587765 --> 0.549307).  Saving model ...
# Sub02 | Exp 1 | Ep 010 | Train 0.6095/63.21% | Val 0.5493/63.92%
# Validation loss decreased (0.549307 --> 0.549237).  Saving model ...
# Validation loss decreased (0.549237 --> 0.519342).  Saving model ...
# Validation loss decreased (0.519342 --> 0.472517).  Saving model ...
# Validation loss decreased (0.472517 --> 0.441206).  Saving model ...
# Validation loss decreased (0.441206 --> 0.436298).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.436298 --> 0.419146).  Saving model ...
# Validation loss decreased (0.419146 --> 0.335307).  Saving model ...
#     Sub02 | Exp 1 | 新的最佳准确率: 65.98% (已保存)
# Validation loss decreased (0.335307 --> 0.304683).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Sub02 | Exp 1 | Ep 020 | Train 0.4178/62.44% | Val 0.3089/63.92%
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Validation loss decreased (0.304683 --> 0.303441).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.303441 --> 0.298676).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Sub02 | Exp 1 | Ep 030 | Train 0.3265/63.99% | Val 0.3872/63.92%
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
#     Sub02 | Exp 1 | 新的最佳准确率: 76.29% (已保存)
# Validation loss decreased (0.298676 --> 0.286693).  Saving model ...
# Validation loss decreased (0.286693 --> 0.267235).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.267235 --> 0.252439).  Saving model ...
# Validation loss decreased (0.252439 --> 0.244803).  Saving model ...
# Validation loss decreased (0.244803 --> 0.233823).  Saving model ...
#     Sub02 | Exp 1 | 新的最佳准确率: 79.38% (已保存)
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Sub02 | Exp 1 | Ep 040 | Train 0.2615/68.14% | Val 0.2405/63.92%
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
#     Sub02 | Exp 1 | 新的最佳准确率: 81.44% (已保存)
# EarlyStopping counter: 8 out of 30
#     Sub02 | Exp 1 | 新的最佳准确率: 83.50% (已保存)
# EarlyStopping counter: 9 out of 30
# Validation loss decreased (0.233823 --> 0.228078).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Sub02 | Exp 1 | Ep 050 | Train 0.2261/75.39% | Val 0.2367/80.41%
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# Sub02 | Exp 1 | Ep 060 | Train 0.2457/77.20% | Val 0.2286/78.35%
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# Validation loss decreased (0.228078 --> 0.228069).  Saving model ...
# Validation loss decreased (0.228069 --> 0.227574).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# Sub02 | Exp 1 | Ep 070 | Train 0.2596/73.06% | Val 0.2334/81.44%
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# Validation loss decreased (0.227574 --> 0.227513).  Saving model ...
# Validation loss decreased (0.227513 --> 0.225677).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Sub02 | Exp 1 | Ep 080 | Train 0.2333/75.91% | Val 0.2422/60.83%
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# Validation loss decreased (0.225677 --> 0.221478).  Saving model ...
# Validation loss decreased (0.221478 --> 0.212316).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# Sub02 | Exp 1 | Ep 090 | Train 0.2408/76.94% | Val 0.2366/72.17%
# EarlyStopping counter: 5 out of 30
# ...
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# Sub35 | Exp 3 | Ep 110 | Train 0.1361/94.26% | Val 0.1282/88.89%
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub35 | Exp 3 | Ep 114 | Train 0.1203/96.17% | Val 0.1283/88.89%
# 早停触发 (基于 Val Loss)。
# 加载 Sub35 (Exp 3) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub35\best_acc_model_exp3.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[28  0  0  0  0]
#  [ 0  6  0  0  5]
#  [ 0  0 10  1  0]
#  [ 0  0  8 34  0]
#  [ 0  0  0  0 52]]
# Normalized Confusion Matrix:
# [[100.           0.           0.           0.           0.        ]
#  [  0.          54.54545455   0.           0.          45.45454545]
#  [  0.           0.          90.90909091   9.09090909   0.        ]
#  [  0.           0.          19.04761905  80.95238095   0.        ]
#  [  0.           0.           0.           0.         100.        ]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub35
# --- 受试者 Sub35 实验 3 完成。最终测试 Acc: 90.28% ---
#
# ============================================================2025-11-11 17:34:19
# --- 正在处理受试者: Sub35 | 实验: 4/5 ---...
#
#   已加载 Sub35: 719 个样本。
# 已实例化 1x1 Stem 适配器 和 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为 Stem 和 分类器 设置优化器 (LD-Net 已冻结)...
#   > 使用 torch.optim.AdamW (lr=0.0005) 训练 Stem 和 分类器。
# Validation loss decreased (inf --> 1.026633).  Saving model ...
#     Sub35 | Exp 4 | 新的最佳准确率: 55.56% (已保存)
# Validation loss decreased (1.026633 --> 1.007078).  Saving model ...
# Validation loss decreased (1.007078 --> 0.993004).  Saving model ...
# Validation loss decreased (0.993004 --> 0.975041).  Saving model ...
# Validation loss decreased (0.975041 --> 0.852900).  Saving model ...
# Validation loss decreased (0.852900 --> 0.745217).  Saving model ...
# Validation loss decreased (0.745217 --> 0.661765).  Saving model ...
# Validation loss decreased (0.661765 --> 0.643127).  Saving model ...
# Validation loss decreased (0.643127 --> 0.592710).  Saving model ...
# Validation loss decreased (0.592710 --> 0.578671).  Saving model ...
# Sub35 | Exp 4 | Ep 010 | Train 0.4860/76.52% | Val 0.5787/49.31%
# Validation loss decreased (0.578671 --> 0.540794).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.540794 --> 0.534854).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.534854 --> 0.499121).  Saving model ...
#     Sub35 | Exp 4 | 新的最佳准确率: 62.50% (已保存)
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.499121 --> 0.461463).  Saving model ...
#     Sub35 | Exp 4 | 新的最佳准确率: 70.14% (已保存)
# Sub35 | Exp 4 | Ep 020 | Train 0.2837/84.52% | Val 0.4615/70.14%
# Validation loss decreased (0.461463 --> 0.223816).  Saving model ...
#     Sub35 | Exp 4 | 新的最佳准确率: 88.89% (已保存)
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
#     Sub35 | Exp 4 | 新的最佳准确率: 90.28% (已保存)
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.223816 --> 0.197185).  Saving model ...
#     Sub35 | Exp 4 | 新的最佳准确率: 91.67% (已保存)
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# Sub35 | Exp 4 | Ep 030 | Train 0.1531/90.09% | Val 0.5335/58.33%
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# Validation loss decreased (0.197185 --> 0.180882).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.180882 --> 0.161811).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.161811 --> 0.150887).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Sub35 | Exp 4 | Ep 040 | Train 0.1339/90.61% | Val 0.1675/87.50%
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# Validation loss decreased (0.150887 --> 0.147354).  Saving model ...
# Sub35 | Exp 4 | Ep 050 | Train 0.1518/89.91% | Val 0.1474/88.89%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# Sub35 | Exp 4 | Ep 060 | Train 0.1144/91.13% | Val 0.1695/87.50%
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# Validation loss decreased (0.147354 --> 0.136563).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Sub35 | Exp 4 | Ep 070 | Train 0.1152/91.30% | Val 0.1588/87.50%
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# Sub35 | Exp 4 | Ep 080 | Train 0.1236/91.13% | Val 0.1476/88.89%
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# Sub35 | Exp 4 | Ep 090 | Train 0.1200/91.30% | Val 0.1662/87.50%
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub35 | Exp 4 | Ep 097 | Train 0.1166/91.48% | Val 0.1768/86.11%
# 早停触发 (基于 Val Loss)。
# 加载 Sub35 (Exp 4) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub35\best_acc_model_exp4.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[28  0  0  0  0]
#  [ 0 11  0  0  0]
#  [ 0  0  0 11  0]
#  [ 0  0  0 42  0]
#  [ 0  0  0  1 51]]
# Normalized Confusion Matrix:
# [[100.           0.           0.           0.           0.        ]
#  [  0.         100.           0.           0.           0.        ]
#  [  0.           0.           0.         100.           0.        ]
#  [  0.           0.           0.         100.           0.        ]
#  [  0.           0.           0.           1.92307692  98.07692308]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub35
# --- 受试者 Sub35 实验 4 完成。最终测试 Acc: 91.67% ---
#
# ============================================================2025-11-11 17:34:30
# --- 正在处理受试者: Sub35 | 实验: 5/5 ---...
#
#   已加载 Sub35: 719 个样本。
# 已实例化 1x1 Stem 适配器 和 SC-BiGRU 分类器。
#   > 使用 FocalLoss (gamma=2) 作为损失函数。
# 正在为 Stem 和 分类器 设置优化器 (LD-Net 已冻结)...
#   > 使用 torch.optim.AdamW (lr=0.0005) 训练 Stem 和 分类器。
# Validation loss decreased (inf --> 1.026909).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 35.42% (已保存)
# Validation loss decreased (1.026909 --> 1.023817).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 36.81% (已保存)
# Validation loss decreased (1.023817 --> 1.012335).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 40.28% (已保存)
# Validation loss decreased (1.012335 --> 0.912109).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 65.28% (已保存)
# Validation loss decreased (0.912109 --> 0.744217).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 81.94% (已保存)
# Validation loss decreased (0.744217 --> 0.577897).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 82.64% (已保存)
# Validation loss decreased (0.577897 --> 0.502606).  Saving model ...
# Validation loss decreased (0.502606 --> 0.468071).  Saving model ...
# Validation loss decreased (0.468071 --> 0.383685).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 83.33% (已保存)
# Validation loss decreased (0.383685 --> 0.346498).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 84.03% (已保存)
# Sub35 | Exp 5 | Ep 010 | Train 0.4238/82.26% | Val 0.3465/84.03%
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.346498 --> 0.311742).  Saving model ...
# Validation loss decreased (0.311742 --> 0.288938).  Saving model ...
# Validation loss decreased (0.288938 --> 0.280140).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.280140 --> 0.276987).  Saving model ...
# Validation loss decreased (0.276987 --> 0.264031).  Saving model ...
# Validation loss decreased (0.264031 --> 0.256002).  Saving model ...
# Validation loss decreased (0.256002 --> 0.255375).  Saving model ...
# Validation loss decreased (0.255375 --> 0.245145).  Saving model ...
# Sub35 | Exp 5 | Ep 020 | Train 0.2638/84.00% | Val 0.2451/84.03%
# Validation loss decreased (0.245145 --> 0.234083).  Saving model ...
# Validation loss decreased (0.234083 --> 0.225072).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.225072 --> 0.219356).  Saving model ...
# Validation loss decreased (0.219356 --> 0.217532).  Saving model ...
# Validation loss decreased (0.217532 --> 0.209335).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.209335 --> 0.203760).  Saving model ...
# Sub35 | Exp 5 | Ep 030 | Train 0.1982/84.35% | Val 0.2038/84.03%
# Validation loss decreased (0.203760 --> 0.196441).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.196441 --> 0.193800).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 86.11% (已保存)
# Validation loss decreased (0.193800 --> 0.192168).  Saving model ...
# Validation loss decreased (0.192168 --> 0.187624).  Saving model ...
# Validation loss decreased (0.187624 --> 0.173269).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 88.19% (已保存)
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.173269 --> 0.172790).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 90.28% (已保存)
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.172790 --> 0.165223).  Saving model ...
# Sub35 | Exp 5 | Ep 040 | Train 0.1543/88.35% | Val 0.1652/86.81%
# Validation loss decreased (0.165223 --> 0.160905).  Saving model ...
# Validation loss decreased (0.160905 --> 0.158322).  Saving model ...
# Validation loss decreased (0.158322 --> 0.154220).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.154220 --> 0.152792).  Saving model ...
# Validation loss decreased (0.152792 --> 0.149548).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
#     Sub35 | Exp 5 | 新的最佳准确率: 90.97% (已保存)
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.149548 --> 0.132857).  Saving model ...
# Sub35 | Exp 5 | Ep 050 | Train 0.1365/88.52% | Val 0.1329/88.89%
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.132857 --> 0.132303).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 95.83% (已保存)
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.132303 --> 0.129467).  Saving model ...
#     Sub35 | Exp 5 | 新的最佳准确率: 96.53% (已保存)
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.129467 --> 0.126358).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Sub35 | Exp 5 | Ep 060 | Train 0.1378/94.26% | Val 0.1553/95.14%
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.126358 --> 0.121096).  Saving model ...
# Validation loss decreased (0.121096 --> 0.118605).  Saving model ...
# Validation loss decreased (0.118605 --> 0.106351).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Validation loss decreased (0.106351 --> 0.099671).  Saving model ...
# Validation loss decreased (0.099671 --> 0.088858).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Sub35 | Exp 5 | Ep 070 | Train 0.0732/97.56% | Val 0.1107/94.44%
# Validation loss decreased (0.088858 --> 0.088421).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# Validation loss decreased (0.088421 --> 0.077836).  Saving model ...
# EarlyStopping counter: 1 out of 30
# EarlyStopping counter: 2 out of 30
# Validation loss decreased (0.077836 --> 0.074459).  Saving model ...
# Validation loss decreased (0.074459 --> 0.056723).  Saving model ...
# EarlyStopping counter: 1 out of 30
# Sub35 | Exp 5 | Ep 080 | Train 0.0588/97.39% | Val 0.0772/94.44%
# EarlyStopping counter: 2 out of 30
# EarlyStopping counter: 3 out of 30
# EarlyStopping counter: 4 out of 30
# EarlyStopping counter: 5 out of 30
# EarlyStopping counter: 6 out of 30
# EarlyStopping counter: 7 out of 30
# EarlyStopping counter: 8 out of 30
# EarlyStopping counter: 9 out of 30
# EarlyStopping counter: 10 out of 30
# EarlyStopping counter: 11 out of 30
# Sub35 | Exp 5 | Ep 090 | Train 0.0501/97.91% | Val 0.0657/94.44%
# EarlyStopping counter: 12 out of 30
# EarlyStopping counter: 13 out of 30
# EarlyStopping counter: 14 out of 30
# EarlyStopping counter: 15 out of 30
# EarlyStopping counter: 16 out of 30
# EarlyStopping counter: 17 out of 30
# EarlyStopping counter: 18 out of 30
# EarlyStopping counter: 19 out of 30
# EarlyStopping counter: 20 out of 30
# EarlyStopping counter: 21 out of 30
# Sub35 | Exp 5 | Ep 100 | Train 0.0489/98.96% | Val 0.0662/95.14%
# EarlyStopping counter: 22 out of 30
# EarlyStopping counter: 23 out of 30
# EarlyStopping counter: 24 out of 30
# EarlyStopping counter: 25 out of 30
# EarlyStopping counter: 26 out of 30
# EarlyStopping counter: 27 out of 30
# EarlyStopping counter: 28 out of 30
# EarlyStopping counter: 29 out of 30
# EarlyStopping counter: 30 out of 30
# Sub35 | Exp 5 | Ep 109 | Train 0.0548/97.39% | Val 0.0671/93.75%
# 早停触发 (基于 Val Loss)。
# 加载 Sub35 (Exp 5) 的最佳模型 (来自: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub35\best_acc_model_exp5.pth)...
# 正在计算并保存混淆矩阵...
# Confusion Matrix:
# [[28  0  0  0  0]
#  [ 0 11  0  0  0]
#  [ 0  0  9  2  0]
#  [ 0  0  0 42  0]
#  [ 0  1  0  2 49]]
# Normalized Confusion Matrix:
# [[100.           0.           0.           0.           0.        ]
#  [  0.         100.           0.           0.           0.        ]
#  [  0.           0.          81.81818182  18.18181818   0.        ]
#  [  0.           0.           0.         100.           0.        ]
#  [  0.           1.92307692   0.           3.84615385  94.23076923]]
# 混淆矩阵已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\Sub35
# --- 受试者 Sub35 实验 5 完成。最终测试 Acc: 96.53% ---
#
# ============================================================2025-11-11 17:34:42
# --- 所有受试者处理完毕 ---...
#
# ✅ 包含50次运行的详细CSV已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\summary_by_subject.csv
# ✅ 【最终报告 (mean+std)】(12行) 已保存到: E:\基于肌电图的下肢运动模式识别\Code2\trainTest\LD_train Test\..\..\results\LD_Net_Online_Classification\SC-BiGRU_Diff_FocalLoss\all_metrics_averaged_results.csv
#
# --- 检查 Sub02 ---
# Sub02 新的5次实验平均准确率: 78.969%
